# %%
import json
import spacy

# %%
# load the training data
with open('training_data.json') as fp:
  training_data = json.load(fp)

# %%
training_data
# Out:
# {'classes': ['NAME ',
#   'EMAIL',
#   'CONTACT',
#   'SKILLS',
#   'EDUCATION',
#   'WORK',
#   'PROJECTS',
#   'ACHIEVEMENTS',
#   'LINKS',
#   'DOB',
#   'CERTIFICATES',
#   'LANGUAGES',
#   'GENDER',
#   'STATUS',
#   'NATIONALITY',
#   'ADDRESS',
#   'FNAME',
#   'OTHERS'],
#  'annotations': [['Sarvesh Dubey', {'entities': [[0, 13, 'NAME ']]}],
#   ['sarvesh91199 @ gmail.com', {'entities': [[0, 22, 'EMAIL']]}],
#   ['+91 831-903-5085', {'entities': [[0, 16, 'CONTACT']]}],
#   ['722-393-1152', {'entities': [[0, 12, 'CONTACT']]}],
#   ['Student | Fresher', {'entities': [[0, 7, 'OTHERS'], [10, 17, 'OTHERS']]}],
#   ['Indore, India', {'entities': [[0, 13, 'ADDRESS']]}],
#   ['Knowing the endgoal and pitching to achieve it',
#    {'entities': [[0, 46, 'OTHERS']]}],
#   ['medium.com/ @ sarvesh_dubey', {'entities': [[0, 25, 'LINKS']]}],
#   ['linkedin com/in/sarvesh-dubey-407325171 in',
#    {'entities': [[0, 39, 'LINKS']]}],
# ...

# %%
# prepare an empty model to train
nlp = spacy.blank('en')
nlp.vocab.vectors.name = 'demo'
ner = nlp.create_pipe('ner')
nlp.add_pipe(ner, last = True)

# %%
# Add the custome NER Tags as entities into the model
for label in training_data["classes"]:
  nlp.entity.add_label(label)

# %%
# Train the model
optimizer = nlp.begin_training()
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\language.py:635: UserWarning: [W033] Training a new parser or NER using a model with an empty lexeme normalization table. This may degrade the performance to some degree. If this is intentional or this language doesn't have a normalization table, please ignore this warning.
#   proc.begin_training(
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\language.py:635: UserWarning: [W034] Please install the package spacy-lookups-data in order to include the default lexeme normalization table for the language 'en'.
#   proc.begin_training(

# %%
training_data["annotations"]
# Out:
# [['Sarvesh Dubey', {'entities': [[0, 13, 'NAME ']]}],
#  ['sarvesh91199 @ gmail.com', {'entities': [[0, 22, 'EMAIL']]}],
#  ['+91 831-903-5085', {'entities': [[0, 16, 'CONTACT']]}],
#  ['722-393-1152', {'entities': [[0, 12, 'CONTACT']]}],
#  ['Student | Fresher', {'entities': [[0, 7, 'OTHERS'], [10, 17, 'OTHERS']]}],
#  ['Indore, India', {'entities': [[0, 13, 'ADDRESS']]}],
#  ['Knowing the endgoal and pitching to achieve it',
#   {'entities': [[0, 46, 'OTHERS']]}],
#  ['medium.com/ @ sarvesh_dubey', {'entities': [[0, 25, 'LINKS']]}],
#  ['linkedin com/in/sarvesh-dubey-407325171 in',
#   {'entities': [[0, 39, 'LINKS']]}],
#  ['github com/sarveshdubey', {'entities': [[0, 23, 'LINKS']]}],
#  ['EDUCATION', {'entities': [[0, 9, 'EDUCATION']]}],
#  ['SKILLS', {'entities': [[0, 6, 'SKILLS']]}],
#  ['B.E: in CSE', {'entities': [[0, 11, 'EDUCATION']]}],
#  ['Pyhthon', {'entities': [[0, 7, 'SKILLS']]}],
#  ['CIC++', {'entities': [[0, 5, 'SKILLS']]}],
# ...

# %%
for text, annotations in training_data["annotations"]:
    if len(text) > 0:
        nlp.update([text], [annotations], sgd=optimizer)
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "sarvesh91199 @ gmail.com" with entities "[[0, 22, 'EMAIL']]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Asus\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "medium.com/ @ sarvesh_dubey" with entities "[[0, 25, 'LINKS']]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# ...

# %%
! python -m spacy download en_core_web_sm
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\asus\appdata\local\programs\python\python39\lib\site-packages)
# ✘ No compatible model found for 'hi_core_web_sm' (spaCy v2.3.5).

# %%
import en_core_web_sm

nlp = en_core_web_sm.load()

# %%
import spacy 
import random
nlp = spacy.load('en_core_web_sm')

# %%
nlp.entity.add_label('NAME')  
nlp.entity.add_label('EMAIL')  
nlp.entity.add_label('DOB')  
nlp.entity.add_label('CONTACT')  
nlp.entity.add_label('SKILLS')  
nlp.entity.add_label('EDUCATION')  
nlp.entity.add_label('WORK')
nlp.entity.add_label('PROJECTS')  
nlp.entity.add_label('ACHIEVEMENTS')  
nlp.entity.add_label('LINKS')  
nlp.entity.add_label('CERTIFICATES')  
nlp.entity.add_label('LANGUAGES')  
nlp.entity.add_label('GENDER')  
nlp.entity.add_label('STATUS')  
nlp.entity.add_label('NATIONALITY')  
nlp.entity.add_label('ADDRESS')  
nlp.entity.add_label('FNAME')  
nlp.entity.add_label('OTHERS')

# %%
TRAIN_DATA = [['Sarvesh Dubey', {'entities': [[0, 13, 'NAME ']]}],
 ['sarvesh91199 @ gmail.com', {'entities': [[0, 22, 'EMAIL']]}],
 ['+91 831-903-5085', {'entities': [[0, 16, 'CONTACT']]}],
 ['722-393-1152', {'entities': [[0, 12, 'CONTACT']]}],
 ['Student | Fresher', {'entities': [[0, 7, 'OTHERS'], [10, 17, 'OTHERS']]}],
 ['Indore, India', {'entities': [[0, 13, 'ADDRESS']]}],
 ['Knowing the endgoal and pitching to achieve it',
  {'entities': [[0, 46, 'OTHERS']]}],
 ['medium.com/ @ sarvesh_dubey', {'entities': [[0, 25, 'LINKS']]}],
 ['linkedin com/in/sarvesh-dubey-407325171 in',
  {'entities': [[0, 39, 'LINKS']]}],
 ['github com/sarveshdubey', {'entities': [[0, 23, 'LINKS']]}],
 ['EDUCATION', {'entities': [[0, 9, 'EDUCATION']]}],
 ['SKILLS', {'entities': [[0, 6, 'SKILLS']]}],
 ['B.E: in CSE', {'entities': [[0, 11, 'EDUCATION']]}],
 ['Pyhthon', {'entities': [[0, 7, 'SKILLS']]}],
 ['CIC++', {'entities': [[0, 5, 'SKILLS']]}],
 ['JavaScript', {'entities': [[0, 10, 'SKILLS']]}],
 ['Django', {'entities': [[0, 6, 'SKILLS']]}],
 ['UIT, Barkatullah University', {'entities': [[0, 27, 'EDUCATION']]}],
 ['2018 - Present', {'entities': [[0, 14, 'EDUCATION']]}],
 ['Bhopal , 8.01 CGPA', {'entities': [[0, 18, 'EDUCATION']]}],
 ['Django Rest Framework', {'entities': [[0, 21, 'SKILLS']]}],
 ['Flask', {'entities': [[0, 5, 'SKILLS']]}],
 ['MERN', {'entities': [[0, 4, 'SKILLS']]}],
 ['Reactjs', {'entities': [[0, 7, 'SKILLS']]}],
 ['High School', {'entities': [[0, 11, 'EDUCATION']]}],
 ['Kendriya Vidyalaya, Indore', {'entities': [[0, 26, 'EDUCATION']]}],
 ['ACHIEVEMENT AND LEADERSHIP', {'entities': [[0, 26, 'ACHIEVEMENTS']]}],
 ['2015 - 2017', {'entities': [[0, 11, 'EDUCATION']]}],
 ['79.8 %', {'entities': [[0, 5, 'EDUCATION']]}],
 ['Website Developer (06/2019 - 08/2019 )',
  {'entities': [[0, 37, 'ACHIEVEMENTS']]}],
 ['Responsible for the development of website for annual technical and',
  {'entities': [[0, 67, 'ACHIEVEMENTS']]}],
 ['cultural fest: Website get viewed by 1000+ candidates :',
  {'entities': [[0, 53, 'ACHIEVEMENTS']]}],
 ['PERSONAL PROJECTS', {'entities': [[0, 17, 'PROJECTS']]}],
 ['Lead Coordinator (07/2019 - 08/2019 )',
  {'entities': [[0, 36, 'ACHIEVEMENTS']]}],
 ['1. Weather Prediction (10/2021 )', {'entities': [[3, 31, 'ACHIEVEMENTS']]}],
 ['One of the few leading coordinator for the event and managed the',
  {'entities': [[0, 60, 'ACHIEVEMENTS']]}],
 ['Django based web app to perform prediction of weather and',
  {'entities': [[0, 53, 'PROJECTS']]}],
 ['budget, negotiations; prizes and other major things',
  {'entities': [[0, 51, 'OTHERS']]}],
 ['retrieve live description of weather for a place. App Fetches',
  {'entities': [[0, 61, 'PROJECTS']]}],
 ['data from OpenWeatherMap.org API and returns the data to',
  {'entities': [[0, 53, 'PROJECTS']]}],
 ['Hacker Rank', {'entities': [[0, 11, 'ACHIEVEMENTS']]}],
 ['Gold badge in Python and C/C++ and 3 stars and counting in Problem',
  {'entities': [[0, 20, 'ACHIEVEMENTS'], [35, 66, 'ACHIEVEMENTS']]}],
 ['Web Scraping', {'entities': [[0, 12, 'SKILLS']]}],
 ['Herokuapp', {'entities': [[0, 9, 'SKILLS']]}],
 ['Knowledge of parsing the htmlxml web pages and fetching required',
  {'entities': [[25, 32, 'SKILLS']]}],
 ['information with BS4 and Selenium',
  {'entities': [[17, 20, 'SKILLS'], [25, 33, 'SKILLS']]}],
 ['2. Party Room (04/2021 - 05/2021 )', {'entities': [[3, 33, 'PROJECTS']]}],
 ['Minor Project Django-React based web app to create a room for',
  {'entities': [[0, 13, 'PROJECTS'], [14, 26, 'SKILLS']]}],
 ['VS Code, Git, Github, MongoDB, Jupyter _',
  {'entities': [[0, 7, 'SKILLS'],
    [9, 12, 'SKILLS'],
    [14, 20, 'SKILLS'],
    [22, 29, 'SKILLS'],
    [31, 40, 'SKILLS']]}],
 ['BeautifulSoup, Postman',
  {'entities': [[0, 13, 'SKILLS'], [15, 22, 'SKILLS']]}],
 ['Used Spotify API to listen songs', {'entities': [[13, 16, 'SKILLS']]}],
 ['Docker, Selenium, PostgreSQL, DigitalOcean, Heroku ,',
  {'entities': [[0, 6, 'SKILLS'],
    [9, 17, 'SKILLS'],
    [20, 30, 'SKILLS'],
    [33, 45, 'SKILLS'],
    [48, 54, 'SKILLS']]}],
 ['Machine Learning', {'entities': [[0, 16, 'SKILLS']]}],
 ['3 . Titanic Survivors (10/2021 )', {'entities': [[4, 31, 'PROJECTS']]}],
 ['MERN based web app to predict the survivor on titanic boat',
  {'entities': [[0, 4, 'SKILLS']]}],
 ['CERTIFICATIONS', {'entities': [[0, 14, 'CERTIFICATES']]}],
 ['not by filling the form: Used pyhton Pickle library to deply the',
  {'entities': [[37, 51, 'SKILLS']]}],
 ['Data Structures and Algorithms (10/2021',
  {'entities': [[0, 30, 'CERTIFICATES']]}],
 ['Python to access Web Data (05/2020 - 06/2020 )',
  {'entities': [[0, 45, 'CERTIFICATES']]}],
 ['4. Django and Chartsjs (10/2021 - 10/2021 )',
  {'entities': [[3, 22, 'CERTIFICATES']]}],
 ['charts Using ApexCharts The charts gives information about',
  {'entities': [[13, 23, 'SKILLS']]}],
 ['Web Dev Training (05/2020 - 07/2020 )',
  {'entities': [[0, 36, 'CERTIFICATES']]}],
 ['Internshala based training', {'entities': [[0, 26, 'CERTIFICATES']]}],
 ['Crash Course on Pyhton', {'entities': [[0, 22, 'CERTIFICATES']]}],
 ['5. User-Admin Network (10/2021', {'entities': [[3, 21, 'PROJECTS']]}],
 ['LANGUAGES', {'entities': [[0, 9, 'PROJECTS']]}],
 ['Serving JWT verification and API testing via Postman in this',
  {'entities': [[0, 52, 'PROJECTS']]}],
 ['English', {'entities': [[0, 7, 'LANGUAGES']]}],
 ['Hindi', {'entities': [[0, 5, 'LANGUAGES']]}],
 ['Django Rest Framework project :', {'entities': [[0, 29, 'PROJECTS']]}],
 ['Sarvesh Dubey', {'entities': [[0, 13, 'NAME ']]}],
 ['sarvesh91199 @ gmailcom', {'entities': [[0, 21, 'EMAIL']]}],
 ['+91 831-903-5085/722-393-1152', {'entities': [[0, 29, 'CONTACT']]}],
 ['Student | Fresher', {'entities': [[0, 7, 'OTHERS'], [10, 17, 'OTHERS']]}],
 ['Knowing the endgoal and pitching to achieve it :',
  {'entities': [[0, 46, 'OTHERS']]}],
 ['Indore, India', {'entities': [[0, 13, 'ADDRESS']]}],
 ['ROLES AND RESPONSIBILITIES', {'entities': [[0, 26, 'ACHIEVEMENTS']]}],
 ['1. Developer and Lead Coordinator',
  {'entities': [[3, 33, 'ACHIEVEMENTS']]}],
 ['Orator', {'entities': [[0, 6, 'ACHIEVEMENTS']]}],
 ['Anchor', {'entities': [[0, 6, 'ACHIEVEMENTS']]}],
 ['Punctual', {'entities': [[0, 8, 'ACHIEVEMENTS']]}],
 ['Django and Populating Database (09/2021 )',
  {'entities': [[0, 30, 'PROJECTS']]}],
 ['Populating and saving data in Django database to be used in the',
  {'entities': [[0, 45, 'PROJECTS']]}],
 ['2.Negotiator and Manager', {'entities': [[0, 24, 'ACHIEVEMENTS']]}],
 ['Blogs regarding Greedy Algorithm (10/2021 )',
  {'entities': [[0, 32, 'PROJECTS']]}],
 ['Regularly took part in sports like chess and football when got',
  {'entities': [[0, 53, 'OTHERS']]}],
 ['Anchored in events in school and college :',
  {'entities': [[0, 40, 'OTHERS']]}],
 ['Playing Football and Chess', {'entities': [[0, 26, 'OTHERS']]}],
 ['Playing Keyboard', {'entities': [[0, 16, 'OTHERS']]}],
 ['Playing Dholak', {'entities': [[0, 14, 'OTHERS']]}],
 ['Cooking', {'entities': [[0, 7, 'OTHERS']]}],
 ['Swimming', {'entities': [[0, 8, 'OTHERS']]}],
 ['Gardening', {'entities': [[0, 9, 'OTHERS']]}],
 ['WORK EXPERIENCE', {'entities': [[0, 15, 'WORK']]}],
 ['6 months', {'entities': [[0, 8, 'WORK']]}],
 ['experience in graphic designing software like Adobe photoshopAdobe illustrator; corel',
  {'entities': [[0, 78, 'WORK']]}],
 ['draw.1 year experience in 2d autocad design Engineering and Solidworks.',
  {'entities': [[0, 22, 'WORK'], [26, 70, 'WORK']]}],
 ['Reading book', {'entities': [[0, 12, 'OTHERS']]}],
 ['Abdul Khan', {'entities': [[0, 10, 'NAME ']]}],
 ['Mr: Firoj Khan', {'entities': [[0, 14, 'FNAME']]}],
 ['18th January 1986', {'entities': [[0, 17, 'DOB']]}],
 ['Male', {'entities': [[0, 4, 'GENDER']]}],
 ['Indian', {'entities': [[0, 6, 'NATIONALITY']]}],
 ['Hindi, English :',
  {'entities': [[0, 5, 'LANGUAGES'], [7, 14, 'LANGUAGES']]}],
 ['Unmarried', {'entities': [[0, 9, 'STATUS']]}],
 ['Village: - Bishunpura ,', {'entities': [[0, 20, 'ADDRESS']]}],
 ['Post: Gohda Bishunpura ,', {'entities': [[0, 24, 'ADDRESS']]}],
 ['Mumbai ,', {'entities': [[0, 6, 'ADDRESS']]}],
 ['Mumbai, Pin-222333.', {'entities': [[8, 18, 'ADDRESS']]}],
 ['( Abdul Khan )', {'entities': [[1, 11, 'NAME ']]}],
 ['3 Year Diploma in Mechanical Engineering (Production) with first division with 68.31% From',
  {'entities': [[0, 40, 'EDUCATION'], [59, 85, 'EDUCATION']]}],
 ['Saraswati Institute of Engineering', {'entities': [[0, 34, 'EDUCATION']]}],
 ['Technology Ghaziabad', {'entities': [[0, 20, 'EDUCATION']]}],
 ['Education, Lucknow, Uttar Pradesh in 2018. And Currently pursing Digital game designing, and',
  {'entities': [[10, 40, 'EDUCATION'], [45, 85, 'EDUCATION']]}],
 ['6 months', {'entities': [[0, 8, 'EDUCATION']]}],
 ['experience graphic designer and pursing video editing',
  {'entities': [[0, 27, 'WORK'], [32, 53, 'WORK']]}],
 ['10th_ Passed with 70% from UP board in 2012 from Gautam public school.',
  {'entities': [[0, 69, 'EDUCATION']]}],
 ['12th-passed with 65% from UP board in 2014 from Sanatan Dharm inter college.',
  {'entities': [[0, 75, 'EDUCATION']]}],
 ['COMPUTER SKILLS', {'entities': [[0, 15, 'SKILLS']]}],
 ['Good knowledge of computer; knowledge of Adobe photoshop, Adobe illustrator; corel draw :',
  {'entities': [[0, 26, 'SKILLS'],
    [27, 55, 'SKILLS'],
    [57, 74, 'SKILLS'],
    [76, 86, 'SKILLS']]}],
 ['STRENGTHS', {'entities': [[0, 9, 'OTHERS']]}],
 ['Positive Attitude', {'entities': [[0, 17, 'OTHERS']]}],
 ['Team Spirit', {'entities': [[0, 11, 'OTHERS']]}],
 ['Hard Working :', {'entities': [[0, 12, 'OTHERS']]}],
 ['DIPLOMA IN AUTO CAD', {'entities': [[0, 19, 'EDUCATION']]}],
 ['1/2018', {'entities': [[0, 6, 'EDUCATION']]}],
 ['CAD DESK', {'entities': [[0, 8, 'EDUCATION']]}],
 ['DIPLOMA IN GRAPHIC DESIGN', {'entities': [[0, 25, 'EDUCATION']]}],
 ['1/2017', {'entities': [[0, 6, 'EDUCATION']]}],
 ['RELIANCE ANIMATION & VFX INSTITUTE INSTITUTE',
  {'entities': [[0, 44, 'EDUCATION']]}],
 ['RITIK', {'entities': [[0, 5, 'NAME ']]}],
 ['NIOS BOARD', {'entities': [[0, 10, 'EDUCATION']]}],
 ['HIGHSCHOOL', {'entities': [[0, 10, 'EDUCATION']]}],
 ['Il2014', {'entities': [[0, 6, 'EDUCATION']]}],
 ['SHARMA', {'entities': [[0, 6, 'NAME ']]}],
 ['CBSE BOARD', {'entities': [[0, 10, 'EDUCATION']]}],
 ['GRAPHIC & UIux DESIGNER', {'entities': [[0, 7, 'WORK'], [10, 23, 'WORK']]}],
 ['CRE TECH :', {'entities': [[0, 8, 'WORK']]}],
 ['I/ March 2019', {'entities': [[0, 13, 'WORK']]}],
 ['Senior Graphic Designer', {'entities': [[0, 23, 'WORK']]}],
 ['A highly talented driven flexible Graphic & UI/Ux Designer',
  {'entities': [[0, 58, 'SKILLS']]}],
 ['with a proven record of delevering creative and innovative',
  {'entities': [[0, 58, 'SKILLS']]}],
 ['Creative Eye', {'entities': [[0, 12, 'SKILLS']]}],
 ['I/ January 2018', {'entities': [[0, 15, 'WORK']]}],
 ['Senior Graphic Designer', {'entities': [[0, 23, 'WORK']]}],
 ['addition to conductive work culture and continuous',
  {'entities': [[0, 50, 'OTHERS']]}],
 ['learning enviornment where my knowledge and',
  {'entities': [[0, 39, 'OTHERS']]}],
 ['technical expretise can be fully utilized :',
  {'entities': [[0, 41, 'OTHERS']]}],
 ['Uppal Packagings', {'entities': [[0, 16, 'WORK']]}],
 ['I/ April 2016', {'entities': [[0, 13, 'WORK']]}],
 ['Graphic Designer', {'entities': [[0, 16, 'WORK']]}],
 ['June 7,1998', {'entities': [[0, 11, 'DOB']]}],
 ['Single', {'entities': [[0, 6, 'STATUS']]}],
 ['Indian', {'entities': [[0, 6, 'NATIONALITY']]}],
 ['PHOTOSHOP', {'entities': [[0, 9, 'SKILLS']]}],
 ['COREL DRAW', {'entities': [[0, 10, 'SKILLS']]}],
 ['English, Hindi', {'entities': [[0, 7, 'LANGUAGES'], [9, 14, 'LANGUAGES']]}],
 ['+91-7906018545', {'entities': [[0, 14, 'CONTACT']]}],
 ['ILLUSTRATOR', {'entities': [[0, 11, 'SKILLS']]}],
 ['AUTOCAD', {'entities': [[0, 7, 'SKILLS']]}],
 ['+91- 8273816476', {'entities': [[5, 15, 'CONTACT']]}],
 ['Address', {'entities': [[0, 7, 'ADDRESS']]}],
 ['Shanti Sadan, Street No. 1', {'entities': [[0, 26, 'ADDRESS']]}],
 ['Goolar Road, Aligarh', {'entities': [[0, 20, 'ADDRESS']]}],
 ['202001', {'entities': [[0, 6, 'ADDRESS']]}],
 ['INDESIGN', {'entities': [[0, 8, 'SKILLS']]}],
 ['ADOBE XD', {'entities': [[0, 8, 'SKILLS']]}],
 ['SKILLS', {'entities': [[0, 6, 'SKILLS']]}],
 ['FIGMA', {'entities': [[0, 5, 'SKILLS']]}],
 ['FILMORA', {'entities': [[0, 7, 'SKILLS']]}],
 ['2D VIDEOS', {'entities': [[0, 9, 'SKILLS']]}],
 ['VIDEO EDITING', {'entities': [[0, 13, 'SKILLS']]}],
 ['BRIDGE', {'entities': [[0, 6, 'SKILLS']]}],
 ['MICROSOFT OFFICE', {'entities': [[0, 16, 'SKILLS']]}],
 ['SOCIAL MEDIA', {'entities': [[0, 12, 'SKILLS']]}],
 ['BRANDING', {'entities': [[0, 8, 'SKILLS']]}],
 ['E-MAILERS', {'entities': [[0, 9, 'SKILLS']]}],
 ['GOOGLE ADS', {'entities': [[0, 10, 'SKILLS']]}],
 ['CREATIVE', {'entities': [[0, 8, 'SKILLS']]}],
 ['CONCEPTS', {'entities': [[0, 8, 'SKILLS']]}],
 ['INNOVATION', {'entities': [[0, 10, 'OTHERS']]}],
 ['TEAM WORK', {'entities': [[0, 9, 'OTHERS']]}],
 ['ART DIRECTION', {'entities': [[0, 13, 'OTHERS']]}],
 ['COMMUNICATION', {'entities': [[0, 13, 'OTHERS']]}],
 ['PHOTOGRAPHY', {'entities': [[0, 11, 'OTHERS']]}],
 ['MUSIC', {'entities': [[0, 5, 'OTHERS']]}],
 ['TRAVELLING', {'entities': [[0, 10, 'OTHERS']]}],
 ['READING', {'entities': [[0, 7, 'OTHERS']]}],
 ['Ritik-sharma-78413a161', {'entities': [[0, 22, 'LINKS']]}],
 ['Sweetritiko1 @ gmail.com', {'entities': [[0, 22, 'EMAIL']]}],
 ['Sunil Kumar Singh', {'entities': [[0, 17, 'FNAME']]}],
 ['( Bachelor of Computer Applications', {'entities': [[1, 34, 'EDUCATION']]}],
 ['BCA )', {'entities': [[0, 3, 'EDUCATION']]}],
 ['E-mail ID: sunilsingh602095 @ gmail.com',
  {'entities': [[11, 37, 'EMAIL']]}],
 ['Contact Number: +91-8130070681', {'entities': [[16, 30, 'CONTACT']]}],
 ['want to utilize my skils and potential to achieve a challenging position. Secure a chalenging',
  {'entities': [[0, 73, 'OTHERS']]}],
 ['position where | can effectively contribute my skills as a Software Professional :',
  {'entities': [[17, 80, 'OTHERS']]}],
 ['B: C. A_', {'entities': [[0, 8, 'EDUCATION']]}],
 ['Makhanlal Chaturvedi', {'entities': [[0, 20, 'EDUCATION']]}],
 ['60.33 %', {'entities': [[0, 7, 'EDUCATION']]}],
 ['2013-2016', {'entities': [[0, 9, 'EDUCATION']]}],
 ['University', {'entities': [[0, 10, 'EDUCATION']]}],
 ['U.P. BOARD', {'entities': [[0, 10, 'EDUCATION']]}],
 ['65.5 %', {'entities': [[0, 5, 'EDUCATION']]}],
 ['2013', {'entities': [[0, 4, 'EDUCATION']]}],
 ['High School', {'entities': [[0, 11, 'EDUCATION']]}],
 ['U.P. BOARD', {'entities': [[0, 10, 'EDUCATION']]}],
 ['59.3 %', {'entities': [[0, 6, 'EDUCATION']]}],
 ['2011', {'entities': [[0, 4, 'EDUCATION']]}],
 ['PHP', {'entities': [[0, 3, 'SKILLS']]}],
 ['Mysql', {'entities': [[0, 5, 'SKILLS']]}],
 ['Wordpress', {'entities': [[0, 9, 'SKILLS']]}],
 ['Codeigniter', {'entities': [[0, 11, 'SKILLS']]}],
 ['OOPs', {'entities': [[0, 4, 'SKILLS']]}],
 ['Jquery', {'entities': [[0, 6, 'SKILLS']]}],
 ['Ajax', {'entities': [[0, 4, 'SKILLS']]}],
 ['Javascript', {'entities': [[0, 10, 'SKILLS']]}],
 ['HTML', {'entities': [[0, 4, 'SKILLS']]}],
 ['CSS', {'entities': [[0, 3, 'SKILLS']]}],
 ['PHP Developer', {'entities': [[0, 13, 'WORK']]}],
 ["SSR TECHVISION Pvt: Ltd. (Feb'2018 - Present )",
  {'entities': [[0, 45, 'WORK']]}],
 ['PHP Developer', {'entities': [[0, 13, 'WORK']]}],
 ["Leading Dots Solution Pvt: Ltd. (Aug'2017 - Jan'2018 )",
  {'entities': [[0, 53, 'WORK']]}],
 ['PHP Developer', {'entities': [[0, 13, 'WORK']]}],
 ["Amj Technologies Pvt: Ltd. (Jan' 2017 _ May' 2017 )",
  {'entities': [[0, 50, 'WORK']]}],
 ['KEY PROJECT HANDLE', {'entities': [[0, 18, 'WORK']]}],
 ['http IIcitymartsupermarketcom (codeigniter framework )',
  {'entities': [[5, 55, 'PROJECTS']]}],
 ['AIl functionality totally handle this project like ecommerce add product listing add product',
  {'entities': [[0, 92, 'PROJECTS']]}],
 ['category subcategory childcategory new post and multi feature functionality',
  {'entities': [[0, 75, 'PROJECTS']]}],
 ['CRM Project (codeigniter framework )', {'entities': [[0, 35, 'PROJECTS']]}],
 ['All functionality totaly handle this project multiple user access authority ,',
  {'entities': [[4, 75, 'PROJECTS']]}],
 ['like excel sheet bulk uploads data and audio recording uploads, downloads',
  {'entities': [[0, 73, 'PROJECTS']]}],
 ['both functionality suppression like different color :',
  {'entities': [[0, 51, 'PROJECTS']]}],
 ['Good Communication Skills.', {'entities': [[0, 25, 'OTHERS']]}],
 ['Good Learner.', {'entities': [[0, 12, 'OTHERS']]}],
 ['Adaptability :', {'entities': [[0, 12, 'OTHERS']]}],
 ['Hard working :', {'entities': [[0, 12, 'OTHERS']]}],
 ['Playing and watching Cricket :', {'entities': [[0, 28, 'OTHERS']]}],
 ['Sunil Kumar Singh', {'entities': [[0, 17, 'NAME ']]}],
 ['Mr. Kailash Singh', {'entities': [[0, 17, 'FNAME']]}],
 ['1Oth July 1995', {'entities': [[0, 14, 'DOB']]}],
 ['Vil - Pachrukhiya, Post - Shankarpatkhauli ,',
  {'entities': [[0, 42, 'ADDRESS']]}],
 ['Dist: - Kushinager U.P.', {'entities': [[0, 22, 'ADDRESS']]}],
 ['274401', {'entities': [[0, 6, 'ADDRESS']]}],
 ['Tekriti Software', {'entities': [[0, 16, 'WORK']]}],
 ['Software Engineer', {'entities': [[0, 17, 'WORK']]}],
 ['May 2011', {'entities': [[0, 8, 'WORK']]}],
 ['April 2012 (1 year )', {'entities': [[0, 19, 'WORK']]}],
 ['Successive Softwares', {'entities': [[0, 20, 'WORK']]}],
 ['Employee', {'entities': [[0, 8, 'WORK']]}],
 ['August 2010 - June 2011 (11 months )', {'entities': [[0, 35, 'WORK']]}],
 ['web developer', {'entities': [[0, 13, 'WORK']]}],
 ['GCET', {'entities': [[0, 4, 'EDUCATION']]}],
 ['MCA, computers . (2007', {'entities': [[0, 22, 'EDUCATION']]}],
 ['2010 )', {'entities': [[0, 5, 'EDUCATION']]}],
 ['DAV Inter college', {'entities': [[0, 17, 'EDUCATION']]}],
 ['12th, Physics . (2002 - 2003 )', {'entities': [[0, 29, 'EDUCATION']]}],
 ['Rohit Bansal', {'entities': [[0, 12, 'NAME ']]}],
 ['9711357476 (Mobile )', {'entities': [[0, 10, 'CONTACT']]}],
 ['rohitbansalzoog @ gmail.com', {'entities': [[0, 25, 'EMAIL']]}],
 ['Solving pain points of recruiters and recruitment processes.',
  {'entities': [[0, 60, 'OTHERS']]}],
 ['Delhi', {'entities': [[0, 5, 'ADDRESS']]}],
 ['www.linkedin comlinlrohit-bansal-', {'entities': [[0, 33, 'LINKS']]}],
 ['0-0940a118 (Linkedln )', {'entities': [[0, 10, 'LINKS']]}],
 ['Rohit is tech consultant involved in providing digital marketing',
  {'entities': [[0, 64, 'OTHERS']]}],
 ['AJAX', {'entities': [[0, 4, 'SKILLS']]}],
 ['JavaScript', {'entities': [[0, 10, 'SKILLS']]}],
 ['jQuery', {'entities': [[0, 6, 'SKILLS']]}],
 ['English', {'entities': [[0, 7, 'LANGUAGES']]}],
 ['Keywords: Digital Marketing Solution, Mobile App, iOS Development ;',
  {'entities': [[10, 36, 'SKILLS'], [38, 48, 'SKILLS'], [50, 65, 'SKILLS']]}],
 ['Android development; Web Development; node: js, Laravel ,',
  {'entities': [[0, 19, 'SKILLS'],
    [21, 36, 'SKILLS'],
    [38, 45, 'SKILLS'],
    [47, 54, 'SKILLS']]}],
 ['Codelgniter; WordPress, Drupal, Python, Core PHP, Mysql ;',
  {'entities': [[0, 11, 'SKILLS'],
    [13, 22, 'SKILLS'],
    [24, 30, 'SKILLS'],
    [32, 38, 'SKILLS'],
    [40, 48, 'SKILLS'],
    [51, 56, 'SKILLS']]}],
 ['MongoDB, AWS, RDS, Elastic Beanstalk; GIT, SVN, eCommerce',
  {'entities': [[0, 7, 'SKILLS'],
    [9, 12, 'SKILLS'],
    [14, 17, 'SKILLS'],
    [19, 36, 'SKILLS'],
    [38, 41, 'SKILLS'],
    [44, 47, 'SKILLS'],
    [49, 58, 'SKILLS']]}],
 ['CredoTree', {'entities': [[0, 9, 'WORK']]}],
 ['Chief Executive Officer', {'entities': [[0, 23, 'WORK']]}],
 ['October 2021', {'entities': [[0, 12, 'WORK']]}],
 ['Present (2 months )', {'entities': [[0, 18, 'WORK']]}],
 ['Noida, Uttar Pradesh, India', {'entities': [[0, 27, 'WORK']]}],
 ['Enthuons Technologies Pvt :', {'entities': [[0, 25, 'WORK']]}],
 ['Director', {'entities': [[0, 8, 'WORK']]}],
 ['January 2014', {'entities': [[0, 12, 'WORK']]}],
 ['Present (7 years 11 months )', {'entities': [[0, 27, 'WORK']]}],
 ['Software Architect Design, Development; Web programming, Strategic and',
  {'entities': [[0, 70, 'WORK']]}],
 ['Technical consultation and Execution.', {'entities': [[0, 37, 'WORK']]}],
 ['Brand development; web site traffic growth; web site Ul and advertising',
  {'entities': [[0, 71, 'WORK']]}],
 ['revenue. Developed brand strategy and statistics systems :',
  {'entities': [[0, 56, 'WORK']]}],
 ['TBS', {'entities': [[0, 3, 'WORK']]}],
 ['Project Manager', {'entities': [[0, 15, 'WORK']]}],
 ['April 2012 - January 2014 (1 year 10 months )',
  {'entities': [[0, 44, 'WORK']]}],
 ['Noida Area, India', {'entities': [[0, 17, 'WORK']]}],
 ['RUPESH THAKUR', {'entities': [[1, 14, 'NAME ']]}],
 ['techrupesh22 @ gmailcom', {'entities': [[1, 22, 'EMAIL']]}],
 ['Contact No: +91-7021717010', {'entities': [[13, 27, 'CONTACT']]}],
 ['CAREER OBJECTIVE', {'entities': [[1, 17, 'OTHERS']]}],
 ['To secure a', {'entities': [[1, 12, 'OTHERS']]}],
 ['responsible career opportunity to fuly utilize my training and skills ,',
  {'entities': [[1, 70, 'OTHERS']]}],
 ['while making a significant contribution to the success of the company :',
  {'entities': [[1, 70, 'OTHERS']]}],
 ['ACADEMIC PROFILE', {'entities': [[1, 17, 'EDUCATION']]}],
 ['STREAM', {'entities': [[1, 7, 'SKILLS']]}],
 ['S.S.C', {'entities': [[1, 6, 'EDUCATION']]}],
 ['RK High School', {'entities': [[1, 15, 'EDUCATION']]}],
 ['BSEB', {'entities': [[1, 5, 'EDUCATION']]}],
 ['PATNA', {'entities': [[1, 6, 'EDUCATION']]}],
 ['2014', {'entities': [[1, 5, 'EDUCATION']]}],
 ['HS.C', {'entities': [[1, 5, 'EDUCATION']]}],
 ['B.N.S.S.N: INTER', {'entities': [[1, 17, 'EDUCATION']]}],
 ['BSEB, PATNA', {'entities': [[1, 13, 'EDUCATION']]}],
 ['2016', {'entities': [[1, 5, 'EDUCATION']]}],
 ['College Muzaffarpur ,', {'entities': [[1, 20, 'EDUCATION']]}],
 ['COPA', {'entities': [[1, 5, 'EDUCATION']]}],
 ['S.J.Z Bhatia ITI', {'entities': [[1, 17, 'EDUCATION']]}],
 ['Maharashtra Board', {'entities': [[1, 18, 'EDUCATION']]}],
 ['2019', {'entities': [[1, 5, 'EDUCATION']]}],
 ['BCA', {'entities': [[1, 4, 'EDUCATION']]}],
 ['Sailee College', {'entities': [[1, 15, 'EDUCATION']]}],
 ['YCMOU Nashik', {'entities': [[1, 13, 'EDUCATION']]}],
 ['2020', {'entities': [[1, 5, 'EDUCATION']]}],
 ['Borivali Mumbai', {'entities': [[1, 16, 'EDUCATION']]}],
 ['TECHNICAL SKILLS :', {'entities': [[1, 17, 'SKILLS']]}],
 ['Python', {'entities': [[1, 7, 'SKILLS']]}],
 ['Framework', {'entities': [[1, 10, 'SKILLS']]}],
 ['Django, Rest API', {'entities': [[1, 7, 'SKILLS'], [9, 17, 'SKILLS']]}],
 ['Web Technologies', {'entities': [[1, 17, 'SKILLS']]}],
 ['HTML, CSS, JavaScript, Bootstrap',
  {'entities': [[1, 5, 'SKILLS'],
    [7, 10, 'SKILLS'],
    [12, 22, 'SKILLS'],
    [24, 33, 'SKILLS']]}],
 ['Database Software', {'entities': [[1, 18, 'SKILLS']]}],
 ['MySQL ,', {'entities': [[1, 6, 'SKILLS']]}],
 ['Software', {'entities': [[1, 9, 'SKILLS']]}],
 ['Git and GitHub', {'entities': [[1, 4, 'SKILLS'], [9, 15, 'SKILLS']]}],
 ['IDEs', {'entities': [[1, 5, 'SKILLS']]}],
 ['Pycharm', {'entities': [[1, 8, 'SKILLS']]}],
 ['Framework', {'entities': [[1, 10, 'SKILLS']]}],
 ['Wordpress', {'entities': [[1, 10, 'SKILLS']]}],
 ['MS-Office', {'entities': [[1, 10, 'SKILLS']]}],
 ['Ms-Word, Ms-Excel, Ms-Powerpoint',
  {'entities': [[1, 8, 'SKILLS'], [10, 18, 'SKILLS'], [20, 33, 'SKILLS']]}],
 ['Flask', {'entities': [[1, 6, 'SKILLS']]}],
 ['Core Java ,', {'entities': [[1, 10, 'SKILLS']]}],
 ['WORK EXPERIENCE :', {'entities': [[1, 16, 'WORK']]}],
 ['Back Office', {'entities': [[1, 12, 'WORK']]}],
 [':6 Month', {'entities': [[1, 9, 'WORK']]}],
 ['Web Development', {'entities': [[1, 16, 'WORK']]}],
 ['3 Month (on WordPress )', {'entities': [[1, 23, 'WORK']]}],
 ['# 1JPROJECT PROFILE: (Project for Institutes )',
  {'entities': [[2, 45, 'WORK']]}],
 ['Project Title', {'entities': [[1, 14, 'PROJECTS']]}],
 ['Blogging Website_', {'entities': [[1, 18, 'PROJECTS']]}],
 ['Domain', {'entities': [[1, 7, 'PROJECTS']]}],
 ['Django', {'entities': [[1, 7, 'SKILLS']]}],
 ['Any blog content here can be added to the database using',
  {'entities': [[1, 57, 'PROJECTS']]}],
 ['Here is adding blog, Signup, login, logout, comments.',
  {'entities': [[1, 53, 'PROJECTS']]}],
 ['# 2) MY PROJECT :', {'entities': [[4, 14, 'PROJECTS']]}],
 ['Look Cars Website, using multi pages', {'entities': [[1, 38, 'PROJECTS']]}],
 ['Good communication and interpersonal skills',
  {'entities': [[1, 44, 'OTHERS']]}],
 ['Focused and confident with positive attitude',
  {'entities': [[1, 45, 'OTHERS']]}],
 ['Self motivated', {'entities': [[1, 15, 'OTHERS']]}],
 ['Listening Music.', {'entities': [[1, 16, 'OTHERS']]}],
 ['Playing Football :', {'entities': [[1, 17, 'OTHERS']]}],
 ['Rupesh Thakur', {'entities': [[1, 14, 'NAME ']]}],
 ['Male', {'entities': [[1, 5, 'GENDER']]}],
 ['Date of Birth', {'entities': [[1, 14, 'DOB']]}],
 ['12/02/1998', {'entities': [[1, 11, 'DOB']]}],
 ['Nationality', {'entities': [[1, 12, 'NATIONALITY']]}],
 ['Indian', {'entities': []}],
 ['English, Hindi, Marathi',
  {'entities': [[1, 8, 'LANGUAGES'],
    [10, 15, 'LANGUAGES'],
    [17, 24, 'LANGUAGES']]}],
 ['+91- 7021717010', {'entities': [[6, 16, 'CONTACT']]}],
 ['Patil nagar, Kandivali (W), Mumbai (suburban) -400067',
  {'entities': [[1, 23, 'ADDRESS'], [27, 50, 'ADDRESS']]}],
 ['SHIVAM', {'entities': [[1, 7, 'NAME ']]}],
 ['Computer Science Engineering', {'entities': [[1, 29, 'EDUCATION']]}],
 ['mittalshivam614 @ gmail.com', {'entities': [[1, 26, 'EMAIL']]}],
 ['+9194168-58227', {'entities': [[1, 15, 'CONTACT']]}],
 ['Uchana Mandi Distt. Jind, India', {'entities': [[1, 32, 'ADDRESS']]}],
 ['linkedin com/in/shivam-mittal-381002222', {'entities': [[1, 40, 'LINKS']]}],
 ['github.com/Shivam-Mittalzooo', {'entities': [[1, 29, 'LINKS']]}],
 ['CAREER OBJECTIVE :', {'entities': [[1, 17, 'OTHERS']]}],
 ['Iwish to excel in an organization which offers growth opportunities and',
  {'entities': [[1, 68, 'OTHERS']]}],
 ['avenues to integrate my Own vision of success with the company and bring out',
  {'entities': [[1, 77, 'OTHERS']]}],
 ['the best of my calibre with total commitment to team work :',
  {'entities': [[1, 58, 'OTHERS']]}],
 ['Shivaniaa Public', {'entities': [[1, 17, 'EDUCATION']]}],
 ['2016', {'entities': [[1, 5, 'EDUCATION']]}],
 ['9.4 CGPA', {'entities': [[1, 9, 'EDUCATION']]}],
 ['( High School )', {'entities': [[2, 13, 'EDUCATION']]}],
 ['School ;', {'entities': [[1, 7, 'EDUCATION']]}],
 ['Uchana Mandi', {'entities': [[1, 13, 'EDUCATION']]}],
 ['( CBSE )', {'entities': [[2, 6, 'EDUCATION']]}],
 ['Senior Secondary', {'entities': [[1, 17, 'EDUCATION']]}],
 ['Shivaniaa Public', {'entities': [[1, 17, 'EDUCATION']]}],
 ['2018', {'entities': [[1, 5, 'EDUCATION']]}],
 ['79.2% /', {'entities': [[1, 6, 'EDUCATION']]}],
 ['School ;', {'entities': [[1, 7, 'EDUCATION']]}],
 ['Uchana Mandi', {'entities': [[1, 13, 'EDUCATION']]}],
 ['( CBSE )', {'entities': [[2, 6, 'EDUCATION']]}],
 ['Bachelor of', {'entities': [[1, 12, 'EDUCATION']]}],
 ['B.S: Anangpuria', {'entities': [[1, 16, 'EDUCATION']]}],
 ['2018-present', {'entities': [[1, 13, 'EDUCATION']]}],
 ['7.91 CGPA', {'entities': [[1, 10, 'EDUCATION']]}],
 ['Technology', {'entities': [[1, 11, 'EDUCATION']]}],
 ['( CSE )', {'entities': [[2, 5, 'EDUCATION']]}],
 ['Institutes ;', {'entities': [[1, 11, 'EDUCATION']]}],
 ['Faridabad (HRY )', {'entities': [[1, 14, 'EDUCATION']]}],
 ['1- Attentive', {'entities': [[4, 13, 'SKILLS']]}],
 ['listening and Good communication and presentation skills.',
  {'entities': [[1, 10, 'SKILLS'], [15, 33, 'SKILLS'], [38, 57, 'SKILLS']]}],
 ['2- Personal integrity and commitment to deadlines.',
  {'entities': [[4, 22, 'SKILLS'], [27, 50, 'SKILLS']]}],
 ['3- Comfortable with programming error handling',
  {'entities': [[4, 47, 'SKILLS']]}],
 ['Familiar with various coding languages such as C; C+t, JAVA (most',
  {'entities': [[48, 49, 'SKILLS'], [51, 54, 'SKILLS'], [56, 60, 'SKILLS']]}],
 ['1-Mobile Information (First Year )', {'entities': [[1, 34, 'PROJECTS']]}],
 ['The basic purpose of this project was to develop an application in which the user',
  {'entities': [[1, 82, 'PROJECTS']]}],
 ['can easily buy an mobile phone to sort their favourite mobile o the basis of their',
  {'entities': [[1, 83, 'PROJECTS']]}],
 ['price, features and specifications.', {'entities': [[1, 35, 'PROJECTS']]}],
 ['2-Chat Messenger (Second Year )', {'entities': [[1, 31, 'PROJECTS']]}],
 ['3-Sorting Visualizer (Third Year )', {'entities': [[1, 34, 'PROJECTS']]}],
 ['implement or visualize the various types of sorting algorithms.',
  {'entities': [[1, 63, 'PROJECTS']]}],
 ['Completed a 2 months online course of AWS cloud architect and AWS cloud',
  {'entities': [[1, 72, 'WORK']]}],
 ['This course was done from ICT Academy', {'entities': [[1, 38, 'WORK']]}],
 ['we are able to develop a good command on cloud computing and Virtualization :',
  {'entities': [[1, 76, 'WORK']]}],
 ['Manmeet Singh Rayet', {'entities': [[1, 20, 'NAME ']]}],
 ['Contact no : 9268765606', {'entities': [[13, 23, 'CONTACT']]}],
 ['Email: manmeet rayet @ yahoo.com', {'entities': [[8, 31, 'EMAIL']]}],
 ['To put my knowledge and skills to the best of my ability for solving challenging and practical problems leading',
  {'entities': [[1, 112, 'OTHERS']]}],
 ['to the development and growth of the development and constantly in the stimulating and learning',
  {'entities': [[1, 96, 'OTHERS']]}],
 ['environment through hard work and sincerity :',
  {'entities': [[1, 44, 'OTHERS']]}],
 ['MBA-Finance', {'entities': [[1, 12, 'EDUCATION']]}],
 ['Neev Education Pvt: Ltd', {'entities': [[1, 24, 'EDUCATION']]}],
 ['Sikkim Manipal', {'entities': [[1, 15, 'EDUCATION']]}],
 ['70 %', {'entities': [[1, 4, 'EDUCATION']]}],
 ['( 2014-2016 )', {'entities': [[2, 11, 'EDUCATION']]}],
 ['University', {'entities': [[1, 11, 'EDUCATION']]}],
 ['B.COM (Programme )', {'entities': [[1, 17, 'EDUCATION']]}],
 ['Guru Nanak Dev Khalsa', {'entities': [[1, 22, 'EDUCATION']]}],
 ['Delhi university', {'entities': [[1, 17, 'EDUCATION']]}],
 ['74 %', {'entities': [[1, 4, 'EDUCATION']]}],
 ['( 2010-2013 )', {'entities': [[2, 11, 'EDUCATION']]}],
 ['College ,', {'entities': [[1, 8, 'EDUCATION']]}],
 ['Karol Bagh, Delhi-05', {'entities': [[1, 21, 'EDUCATION']]}],
 ['Class XII (2010 )', {'entities': [[1, 17, 'EDUCATION']]}],
 ['G.H.P.S Shahadra', {'entities': [[1, 17, 'EDUCATION']]}],
 ['CBS.E_', {'entities': [[1, 7, 'EDUCATION']]}],
 ['78 %', {'entities': [[1, 4, 'EDUCATION']]}],
 ['Class X (2008 )', {'entities': [[1, 15, 'EDUCATION']]}],
 ['G.H.P.S Shahadra', {'entities': [[1, 17, 'EDUCATION']]}],
 ['CBSE :', {'entities': [[1, 6, 'EDUCATION']]}],
 ['76 %', {'entities': [[1, 4, 'EDUCATION']]}],
 ['CIA + (Certified Industrial Accountant )',
  {'entities': [[1, 39, 'SKILLS']]}],
 ['ICA (Institute Of Computer Accountants), Preet Vihar, Delhi-92',
  {'entities': [[1, 62, 'WORK']]}],
 ['Working experience with advance Excel.', {'entities': [[1, 38, 'SKILLS']]}],
 ['Working experience with Google drive :',
  {'entities': [[25, 37, 'SKILLS']]}],
 ['Working experience with Tally ERP 9', {'entities': [[25, 36, 'SKILLS']]}],
 ['Knowledge of Microsoft Navision 2013 (ERP Software )',
  {'entities': [[14, 32, 'SKILLS'], [39, 51, 'SKILLS']]}],
 ['Knowledge of Busy 3.9', {'entities': [[14, 22, 'SKILLS']]}],
 ['Working as " Senior Accounts Executive " in Minar Travels India Pvt: Ltd. since 28th May 2019 to',
  {'entities': [[13, 38, 'WORK'], [43, 72, 'WORK'], [79, 92, 'WORK']]}],
 ['Working as " Senior Accounts Officer " in Holiday Triangle Travel Pvt: Ltd. since 21th March 2016',
  {'entities': [[13, 36, 'WORK'], [41, 74, 'WORK'], [81, 96, 'WORK']]}],
 ['to 27th May 2019.', {'entities': [[4, 17, 'WORK']]}],
 ['Worked as " Accounts Assistant " in Bravia International General Trding LLC, Dubai from 30th',
  {'entities': [[12, 30, 'WORK'], [35, 74, 'WORK'], [76, 91, 'WORK']]}],
 ['April 2015 to 15th February 2016', {'entities': [[1, 33, 'WORK']]}],
 ['Worked as " Accounts Assistant " in AgreeYa Solutions India Private Limited on behalf of Lochan',
  {'entities': [[12, 30, 'WORK'], [35, 74, 'WORK']]}],
 ['& Co. (CA Firm) from 18th November 2013 to 15th December 2014.',
  {'entities': [[7, 14, 'WORK'], [21, 61, 'WORK']]}],
 ['Job Responsibilities_in Minar Travels India Pvt_Ltd',
  {'entities': [[1, 52, 'WORK']]}],
 ['Recording transactions on daily basis in Tally.',
  {'entities': [[1, 47, 'PROJECTS']]}],
 ['Reconciliation of Bank Statements on daily basis.',
  {'entities': [[1, 49, 'PROJECTS']]}],
 ["Preparing Hotel vendor's payment cheques & reconciliation of the same",
  {'entities': [[1, 70, 'PROJECTS']]}],
 ['Reconciliation of Imprest Accounts :', {'entities': [[1, 35, 'PROJECTS']]}],
 ['Preparing department wise Salary data & recording the entries in Tally :',
  {'entities': [[1, 33, 'PROJECTS'], [41, 71, 'PROJECTS']]}],
 ['Preparing of TDS details & assist in finalization of TDS return :',
  {'entities': [[1, 25, 'PROJECTS'], [54, 64, 'PROJECTS']]}],
 ['Preparing GST data for GSTR-1 & GSTR-3B & filing the same_',
  {'entities': [[1, 19, 'PROJECTS'],
    [20, 30, 'PROJECTS'],
    [33, 40, 'PROJECTS']]}],
 ['Reconciliation of GSTR-ZA, GSTR-1 & GSTR-3B with Tally quarterly.',
  {'entities': [[19, 26, 'PROJECTS'],
    [29, 35, 'PROJECTS'],
    [38, 66, 'PROJECTS']]}],
 ['Monthly closing of bank accounts & updation in Tally :',
  {'entities': [[1, 53, 'PROJECTS']]}],
 ['Weekly reconciliation of bank accounts in Taly as well as in excel format :',
  {'entities': [[1, 74, 'PROJECTS']]}],
 ['Akbar Travels, TSI Yatra Pvt Itd, Mystifly )',
  {'entities': [[1, 44, 'ACHIEVEMENTS']]}],
 ["Monthly reconciliation of vendor's accounts for Hotel, sightseen, land package & visa.",
  {'entities': [[1, 54, 'ACHIEVEMENTS'],
    [56, 65, 'ACHIEVEMENTS'],
    [72, 86, 'ACHIEVEMENTS']]}],
 ['Proceeding payments to supplier through NEFT, RTGS, Cheques, IMPS on daily basis',
  {'entities': [[1, 45, 'ACHIEVEMENTS'],
    [47, 51, 'ACHIEVEMENTS'],
    [53, 60, 'ACHIEVEMENTS'],
    [62, 75, 'ACHIEVEMENTS']]}],
 ['Job Responsibilities in Bravia International General Trding LLC_Dubai',
  {'entities': [[1, 70, 'ACHIEVEMENTS']]}],
 ['Recording General transactions in Tally & ERP software',
  {'entities': [[1, 55, 'ACHIEVEMENTS']]}],
 ['Reconciling Bank Statements on monthly basis.',
  {'entities': [[1, 45, 'ACHIEVEMENTS']]}],
 ['Recording Sales and purchase invoices and credit notes in ERP system.',
  {'entities': [[1, 69, 'ACHIEVEMENTS']]}],
 ['Responsible for preparing monthly Stock valuation & ageing report',
  {'entities': [[1, 66, 'ACHIEVEMENTS']]}],
 ['Sh Amarjeet Singh Rayet', {'entities': [[1, 24, 'FNAME']]}],
 ['1st December1991', {'entities': [[1, 17, 'DOB']]}],
 ['H-7 Radhey Puri_Krishna Nagar, New Delhi-110051',
  {'entities': [[1, 47, 'ADDRESS']]}],
 ['manmeet ravet @ yahoo com_', {'entities': [[1, 25, 'EMAIL']]}],
 ['9268765606', {'entities': [[1, 11, 'CONTACT']]}],
 ['Indian', {'entities': [[1, 7, 'NATIONALITY']]}],
 ['Single', {'entities': [[1, 7, 'STATUS']]}],
 ['( MANMEET SINGH RAYET )', {'entities': [[2, 21, 'NAME ']]}],
 ['ZARANA HEER SONI', {'entities': [[1, 17, 'NAME ']]}],
 ['Scarborough, Ontario', {'entities': [[1, 21, 'ADDRESS']]}],
 ['C: +1 647 674 8019 E-mail: zsoni4556 @ gmail com',
  {'entities': [[6, 18, 'CONTACT'], [27, 46, 'EMAIL']]}],
 ["Over 5 years' experience as a Transaction Advisory Associate with proven Management ,",
  {'entities': [[1, 84, 'WORK']]}],
 ['Analytical and Organizational skills :',
  {'entities': [[1, 11, 'SKILLS'], [16, 37, 'SKILLS']]}],
 ['Chartered Secretary (India), Bachelor of Law and Bachelor of Commerce with major in',
  {'entities': [[1, 20, 'WORK'],
    [22, 27, 'WORK'],
    [30, 45, 'EDUCATION'],
    [50, 70, 'EDUCATION']]}],
 ['accounting and auditing',
  {'entities': [[1, 11, 'SKILLS'], [16, 24, 'SKILLS']]}],
 ['Knowledge of Corporate, RBI and SEBI laws',
  {'entities': [[14, 23, 'SKILLS'],
    [25, 28, 'SKILLS'],
    [33, 37, 'SKILLS'],
    [38, 42, 'SKILLS']]}],
 ['Proficient in Microsoft Excel, Word, Power Point and Outlook',
  {'entities': [[15, 30, 'SKILLS'],
    [32, 36, 'SKILLS'],
    [38, 49, 'SKILLS'],
    [54, 61, 'SKILLS']]}],
 ['Experience in assisting Mergers and Amalgamations',
  {'entities': [[1, 32, 'WORK'], [37, 50, 'WORK']]}],
 ['Demonstrated skills in the areas of Insolvency and Bankruptcy Laws',
  {'entities': [[28, 47, 'SKILLS'], [52, 67, 'SKILLS']]}],
 ['Highly organized and competent to work independently and collaboratively with',
  {'entities': [[1, 19, 'SKILLS'],
    [24, 33, 'SKILLS'],
    [37, 55, 'SKILLS'],
    [60, 75, 'SKILLS']]}],
 ['Ability to adapt to fast paced work environments, ability to work on time, influential',
  {'entities': [[76, 87, 'SKILLS']]}],
 ['team leader (have also trained few apprentice during my career), who has successfully',
  {'entities': [[1, 12, 'SKILLS']]}],
 ['BDO India LLP (Mumbai; India )', {'entities': [[1, 29, 'WORK']]}],
 ['Associate ~ Transaction Tax & Regulatory Services',
  {'entities': [[1, 10, 'WORK'], [13, 28, 'WORK'], [31, 50, 'WORK']]}],
 ['Oct 2018 ~ April 2021', {'entities': [[1, 22, 'WORK']]}],
 ['Assisted Resolution Professional in the Corporate Insolvency Resolution Process',
  {'entities': [[1, 33, 'WORK'], [41, 72, 'WORK']]}],
 ['Drafted Resolution Plan, Minutes of the meetings for Committee of Creditors and',
  {'entities': [[1, 24, 'WORK'], [26, 76, 'WORK']]}],
 ['meeting of Resolution Professional with other financial institutions',
  {'entities': [[12, 35, 'WORK'], [47, 69, 'WORK']]}],
 ['Appeared before National Company Law Tribunal for presenting the Resolution Plan',
  {'entities': [[1, 46, 'WORK'], [66, 81, 'WORK']]}],
 ['Incorporated Private/Public Limited Companies and Limited Liability Partnerships',
  {'entities': [[1, 28, 'WORK'], [29, 46, 'WORK'], [51, 81, 'WORK']]}],
 ['Conducted Due Diligence of various Corporations',
  {'entities': [[1, 24, 'WORK']]}],
 ['SGC0 Co. & LLP (Mumbai, India )',
  {'entities': [[1, 15, 'WORK'], [17, 30, 'WORK']]}],
 ['Executive', {'entities': [[1, 10, 'WORK']]}],
 ['April 2016 _ Sept 2018', {'entities': [[1, 23, 'WORK']]}],
 ['Assisted Partner in Initial Public Offer (IPO) of Small and Medium Enterprise (SME )',
  {'entities': [[1, 35, 'WORK'], [51, 78, 'WORK']]}],
 ['various approvals from the Bombay Stock Exchange',
  {'entities': [[9, 49, 'WORK']]}],
 ['Converted Private Limited Company into Public Limited Company and Vice',
  {'entities': [[1, 62, 'ACHIEVEMENTS']]}],
 ['Handled RBI Compliances for Non-Banking Financial Corporation and SEBI Compliances',
  {'entities': [[1, 24, 'ACHIEVEMENTS'],
    [29, 62, 'ACHIEVEMENTS'],
    [67, 83, 'ACHIEVEMENTS']]}],
 ['as per Merchant Bankers Regulations',
  {'entities': [[8, 36, 'ACHIEVEMENTS']]}],
 ['Intern of Listed Department', {'entities': [[1, 28, 'ACHIEVEMENTS']]}],
 ['Jan 2015 - Feb 2016', {'entities': [[5, 20, 'ACHIEVEMENTS']]}],
 ['Graduate Certificate in Business Analytics from Seneca College (May 2021 - Present )',
  {'entities': [[1, 63, 'EDUCATION'], [65, 83, 'EDUCATION']]}],
 ['Bachelor of Law from Mumbai University (2017 )',
  {'entities': [[1, 39, 'EDUCATION'], [41, 45, 'EDUCATION']]}],
 ["Company Secretary from 'The Institute of Company Secretaries of India' (2015 )",
  {'entities': [[1, 18, 'EDUCATION'],
    [24, 70, 'EDUCATION'],
    [73, 77, 'EDUCATION']]}],
 ['Bachelor of Commerce from University of Mumbai _ (Accounting) (2014 )',
  {'entities': [[1, 47, 'EDUCATION'],
    [51, 61, 'EDUCATION'],
    [64, 68, 'EDUCATION']]}],
 ['Name: Auti Ramesh Kisan', {'entities': [[6, 23, 'NAME ']]}],
 ['Address: Bhavani Complex, Near Ashwini Hospital, Balewadi; Pune-413045',
  {'entities': [[11, 26, 'ADDRESS'],
    [28, 49, 'ADDRESS'],
    [51, 59, 'ADDRESS'],
    [61, 72, 'ADDRESS']]}],
 ['Mobile : 9607118006', {'entities': [[9, 19, 'CONTACT']]}],
 ['E-Mail- rameshautil24 @ gmail com', {'entities': [[9, 32, 'EMAIL']]}],
 ['accumulate knowledge and become the best in the performance circle, with innovation',
  {'entities': [[49, 67, 'EMAIL']]}],
 ['Java, Angular, JavaScript; Spring, Spring boot',
  {'entities': [[1, 5, 'LANGUAGES'],
    [8, 15, 'LANGUAGES'],
    [18, 28, 'LANGUAGES'],
    [30, 36, 'LANGUAGES'],
    [39, 50, 'LANGUAGES']]}],
 ['Microservices, NodeJs, ExpressJs, MySQL, CSS',
  {'entities': [[1, 14, 'LANGUAGES'],
    [16, 22, 'LANGUAGES'],
    [25, 34, 'LANGUAGES'],
    [36, 41, 'LANGUAGES'],
    [43, 46, 'LANGUAGES']]}],
 ['Server', {'entities': [[1, 7, 'LANGUAGES']]}],
 ['Apache Tomcat', {'entities': [[1, 14, 'LANGUAGES']]}],
 ['IDE', {'entities': [[1, 4, 'LANGUAGES']]}],
 ['Eclipse, NetBeans, VsCode',
  {'entities': [[1, 8, 'LANGUAGES'],
    [11, 19, 'LANGUAGES'],
    [21, 27, 'LANGUAGES']]}],
 ['MongoDB', {'entities': [[1, 8, 'LANGUAGES']]}],
 ['BCS', {'entities': [[1, 4, 'EDUCATION']]}],
 ['Pune University', {'entities': [[1, 16, 'EDUCATION']]}],
 ['Vidya Pratisthan College Baramati', {'entities': [[1, 34, 'EDUCATION']]}],
 ['63.3', {'entities': [[1, 5, 'EDUCATION']]}],
 ['2018-19', {'entities': [[1, 8, 'EDUCATION']]}],
 ['HSC', {'entities': [[1, 4, 'EDUCATION']]}],
 ['Maharashtra Board', {'entities': [[1, 18, 'EDUCATION']]}],
 ['Mahadaji Shinde Vidyalaya', {'entities': [[1, 26, 'EDUCATION']]}],
 ['52.72', {'entities': [[1, 6, 'EDUCATION']]}],
 ['2014-15', {'entities': [[1, 8, 'EDUCATION']]}],
 ['Shrigonda', {'entities': [[1, 10, 'EDUCATION']]}],
 ['SSC', {'entities': [[1, 4, 'EDUCATION']]}],
 ['Maharashtra Board', {'entities': [[1, 18, 'EDUCATION']]}],
 ['Mahadaji Shinde Vidyalaya', {'entities': [[1, 26, 'EDUCATION']]}],
 ['67.80', {'entities': [[1, 6, 'EDUCATION']]}],
 ['2012-13', {'entities': [[1, 8, 'EDUCATION']]}],
 ['Shrigonda', {'entities': [[1, 10, 'EDUCATION']]}],
 ['Shop Management System :', {'entities': [[1, 23, 'PROJECTS']]}],
 ['Angular, Core Java, Spring boot, HTML, MYSQL.',
  {'entities': [[1, 9, 'SKILLS'],
    [9, 18, 'SKILLS'],
    [20, 31, 'SKILLS'],
    [32, 36, 'SKILLS'],
    [37, 42, 'SKILLS']]}],
 ['visual studio Code 2019, STS, Eclipse',
  {'entities': [[1, 19, 'SKILLS'], [26, 29, 'SKILLS'], [30, 37, 'SKILLS']]}],
 ['generate few reports', {'entities': [[1, 21, 'PROJECTS']]}],
 ['Minor Projects', {'entities': [[1, 15, 'PROJECTS']]}],
 ['Photoshoppe Management System', {'entities': [[1, 30, 'PROJECTS']]}],
 ['Techonology used: Java, HTML, MYSQL',
  {'entities': [[19, 23, 'SKILLS'], [24, 28, 'SKILLS'], [29, 34, 'SKILLS']]}],
 ['NetBeans', {'entities': [[1, 9, 'SKILLS']]}],
 ['Description: Phtotoshopee is develop managing a store photo.Create',
  {'entities': [[14, 67, 'PROJECTS']]}],
 ['Sales Report fast moving details price list of items.',
  {'entities': [[1, 18, 'PROJECTS'], [19, 39, 'PROJECTS']]}],
 ['Ramesh Auti', {'entities': [[1, 12, 'NAME ']]}],
 ['Kisan B Auti', {'entities': [[1, 13, 'EMAIL']]}],
 ['Jun 12 , 1997', {'entities': [[1, 13, 'DOB']]}],
 ['Male', {'entities': [[1, 5, 'GENDER']]}],
 ['Unmarried', {'entities': [[1, 10, 'STATUS']]}],
 ['English; Hindi, Marathi',
  {'entities': [[1, 8, 'LANGUAGES'],
    [10, 15, 'LANGUAGES'],
    [16, 23, 'LANGUAGES']]}],
 ['rameshautil 24 @ gmail com', {'entities': [[1, 25, 'EMAIL']]}],
 ['Auti Ramesh Kisan', {'entities': [[1, 18, 'FNAME']]}],
 ['Graphics & Web Designer with 2.5 years of experience.',
  {'entities': [[1, 24, 'WORK'], [30, 53, 'WORK']]}],
 ['Im hard working individual with a great attention',
  {'entities': [[4, 16, 'WORK'], [35, 50, 'WORK']]}],
 ['enjoy new and challenging projects.',
  {'entities': [[1, 35, 'ACHIEVEMENTS']]}],
 ['NAMRATA', {'entities': [[1, 8, 'NAME ']]}],
 ['MAhAWER', {'entities': [[1, 8, 'NAME ']]}],
 ['2021-Present', {'entities': [[1, 13, 'EDUCATION']]}],
 ['IGNOU', {'entities': [[1, 6, 'EDUCATION']]}],
 ['Wel & Gnaphice Deaigner', {'entities': [[1, 24, 'WORK']]}],
 ['Master of Arts (English )',
  {'entities': [[1, 15, 'EDUCATION'], [17, 24, 'EDUCATION']]}],
 ['2017-2021', {'entities': [[1, 10, 'EDUCATION']]}],
 ['Delhi University', {'entities': [[1, 17, 'EDUCATION']]}],
 ['Bachelor of Arts (Hindi )',
  {'entities': [[1, 17, 'EDUCATION'], [19, 24, 'EDUCATION']]}],
 ['2018-2020', {'entities': [[1, 10, 'EDUCATION']]}],
 ['Arena Animation', {'entities': [[1, 16, 'EDUCATION']]}],
 ['Digital Graphic Animation', {'entities': [[1, 26, 'EDUCATION']]}],
 ['2016-2017', {'entities': [[1, 10, 'EDUCATION']]}],
 ['R.S.K.V. Kalyan Puri', {'entities': [[1, 21, 'EDUCATION']]}],
 ['CBSE Board 12th', {'entities': [[1, 16, 'EDUCATION']]}],
 ['83.75', {'entities': [[1, 6, 'EDUCATION']]}],
 ['fornamrata27 @ gmail.com', {'entities': [[1, 23, 'EMAIL']]}],
 ['R.SK.V. Kalyan Puri', {'entities': [[1, 20, 'EDUCATION']]}],
 ['CBSE Board 1Oth', {'entities': [[1, 16, 'EDUCATION']]}],
 ['70.2', {'entities': [[1, 5, 'EDUCATION']]}],
 ['9899901458', {'entities': [[1, 11, 'CONTACT']]}],
 ['? ank Expenience', {'entities': [[6, 16, 'WORK']]}],
 ['Analog Webmedia Pvt: Ltd, Noida :', {'entities': [[1, 33, 'WORK']]}],
 ['7 Months', {'entities': [[1, 9, 'WORK']]}],
 ['PantLalio', {'entities': [[1, 10, 'WORK']]}],
 ['April 2021', {'entities': [[1, 11, 'WORK']]}],
 ['October 2021', {'entities': [[1, 13, 'WORK']]}],
 ['Dignitech Media Pvt: Ltd., Noida :', {'entities': [[1, 33, 'WORK']]}],
 ['10 Months', {'entities': [[1, 10, 'WORK']]}],
 ['Be', {'entities': [[1, 3, 'WORK']]}],
 ['https: //wwwbehance net/namratamahawer', {'entities': [[1, 38, 'LINKS']]}],
 ['in) https: //www.linkedin com/in/namrata-',
  {'entities': [[5, 41, 'LINKS']]}],
 ['Copy Desk, Jhandewalan, New Delhi.', {'entities': [[1, 34, 'WORK']]}],
 ['1 Year', {'entities': [[1, 7, 'WORK']]}],
 ['mahawer-b723291aa/', {'entities': [[1, 19, 'LINKS']]}],
 ['April 2019', {'entities': [[1, 11, 'WORK']]}],
 ['March 2020', {'entities': []}],
 ['Ai', {'entities': [[1, 3, 'SKILLS']]}],
 ['Adobe Illustrator', {'entities': [[1, 18, 'SKILLS']]}],
 ['Adobe Premiere', {'entities': [[1, 15, 'SKILLS']]}],
 ['Adobe Photoshop', {'entities': [[1, 16, 'SKILLS']]}],
 ['CorelDRAW', {'entities': [[1, 10, 'SKILLS']]}],
 ['Adobe XD', {'entities': [[1, 9, 'SKILLS']]}],
 ['Figma', {'entities': [[1, 6, 'SKILLS']]}],
 ['Adobe InDesign', {'entities': [[1, 15, 'SKILLS']]}],
 ['Microsoft Power Point',
  {'entities': [[1, 16, 'SKILLS'], [17, 22, 'SKILLS']]}],
 ['Monu Kumar', {'entities': [[1, 11, 'NAME ']]}],
 ['Village-Khanpur; Post-Butrara ,', {'entities': [[1, 30, 'ADDRESS']]}],
 ['District-Shamli (U.P )', {'entities': [[1, 22, 'ADDRESS']]}],
 ['Software Engineer', {'entities': [[1, 18, 'EDUCATION']]}],
 ['+918700982075', {'entities': [[1, 14, 'CONTACT']]}],
 ['monumittal21Sg8 @ gmail.com', {'entities': [[1, 26, 'EMAIL']]}],
 ['https /IwWW linkedin comlinmonu-kumar-957260157L',
  {'entities': [[1, 49, 'LINKS']]}],
 ['https: [Lgithub com [MonuKumar12345', {'entities': [[1, 36, 'LINKS']]}],
 ['Started working as a Software engineer with eagerness to learn new skills and abilities in the future :',
  {'entities': [[1, 102, 'OTHERS']]}],
 ['Continuing with the same aim and ability at best with a new environment and people',
  {'entities': [[1, 83, 'OTHERS']]}],
 ['Ambedkar Institute Of Advanced Communication Technologies & Research ,',
  {'entities': [[1, 69, 'EDUCATION']]}],
 ['Delhi 110031', {'entities': [[1, 13, 'EDUCATION']]}],
 ['B.Tech', {'entities': [[1, 7, 'EDUCATION']]}],
 ['2016', {'entities': [[1, 5, 'EDUCATION']]}],
 ['2020', {'entities': [[1, 5, 'EDUCATION']]}],
 ['CGPA', {'entities': [[1, 5, 'EDUCATION']]}],
 ['8.6', {'entities': [[1, 4, 'EDUCATION']]}],
 ["DE'SAINT PUBLIC SCHOOL, Shamli (U.P) - 12th",
  {'entities': [[1, 44, 'EDUCATION']]}],
 ['2015', {'entities': [[1, 5, 'EDUCATION']]}],
 ['Aggregate : 85.6 %', {'entities': [[1, 17, 'EDUCATION']]}],
 ["DE'SAINT PUBLIC SCHOOL; Shamli (UP) _ 1oth",
  {'entities': [[1, 43, 'EDUCATION']]}],
 ['2013', {'entities': [[1, 5, 'EDUCATION']]}],
 ['CGPA : 9.8', {'entities': [[1, 10, 'EDUCATION']]}],
 ['Moderate in Html, Css, Bootstrap, Javascript, Jquery, Ajax, Php, Mysgl, Angularjs, C++',
  {'entities': [[13, 17, 'SKILLS'],
    [19, 22, 'SKILLS'],
    [24, 33, 'SKILLS'],
    [35, 45, 'SKILLS'],
    [47, 53, 'SKILLS'],
    [55, 59, 'SKILLS'],
    [61, 64, 'SKILLS'],
    [66, 71, 'SKILLS'],
    [73, 82, 'SKILLS'],
    [84, 87, 'SKILLS']]}],
 ['Beginner in Node Js, Reactjs, MongoDB',
  {'entities': [[13, 20, 'SKILLS'], [22, 29, 'SKILLS'], [31, 38, 'SKILLS']]}],
 ['Tools: Git; Docker; VSCode, Jira',
  {'entities': [[8, 11, 'SKILLS'],
    [13, 19, 'SKILLS'],
    [21, 27, 'SKILLS'],
    [29, 33, 'SKILLS']]}],
 ['Rawcubes India Pvt Ltd, Noida-201301-Software Engineer',
  {'entities': [[1, 23, 'WORK'], [25, 55, 'WORK']]}],
 ['February 2021', {'entities': [[1, 14, 'WORK']]}],
 ['Present', {'entities': [[1, 8, 'WORK']]}],
 ['Working on front end part', {'entities': [[1, 26, 'WORK']]}],
 ['Working on backend part', {'entities': [[1, 24, 'WORK']]}],
 ['RG SmartDiscovery LLP, Delhi-110085_Software Developer',
  {'entities': [[1, 22, 'WORK'], [25, 56, 'WORK']]}],
 ['November 2020 - February 2021',
  {'entities': [[1, 14, 'WORK'], [17, 30, 'WORK']]}],
 ['DataPitcher', {'entities': [[1, 12, 'WORK']]}],
 ['Develop front-End using AngularJs with Bootstrap and Jquery :',
  {'entities': [[1, 18, 'WORK'], [25, 60, 'WORK']]}],
 ['Integrate RestApis.', {'entities': [[1, 19, 'WORK']]}],
 ['RG SmartDiscovery LLP, Delhi-110085-_Software Engineer Intern',
  {'entities': [[1, 22, 'WORK'], [24, 62, 'WORK']]}],
 ['July 2019', {'entities': [[1, 10, 'WORK']]}],
 ['November 2020', {'entities': [[1, 14, 'WORK']]}],
 ['Develop front-End with Html, Css, Bootstrap and Jquery',
  {'entities': [[1, 18, 'WORK']]}],
 ['Integrate RestApis.', {'entities': [[1, 19, 'WORK']]}],
 ['Website: https: Lwomenmark comL', {'entities': [[10, 31, 'LINKS']]}],
 ['3. DataPitcher', {'entities': [[6, 17, 'ACHIEVEMENTS']]}],
 ['organizations & research companies with platforms to monetize and exchange data in a regulated economy',
  {'entities': [[1, 103, 'OTHERS']]}],
 ['Integrate RestApis.', {'entities': [[11, 19, 'SKILLS']]}],
 ['Website: https: LLWWWdatapitcher coml', {'entities': [[10, 37, 'LINKS']]}],
 ['Mohammed Asif', {'entities': [[1, 14, 'NAME ']]}],
 ['( +91) 8318236252', {'entities': [[7, 17, 'CONTACT']]}],
 ['QQZasifkhan1991 @ gmaiLcom', {'entities': [[1, 25, 'EMAIL']]}],
 ['Sound knowledge of Development; SEO, Content Writing and Facilitation.',
  {'entities': [[33, 36, 'SKILLS'], [38, 53, 'SKILLS'], [58, 70, 'SKILLS']]}],
 ['linkedin: comlinmohammedasif1991', {'entities': [[1, 32, 'LINKS']]}],
 ["BYJU' $, Bengaluru", {'entities': [[1, 19, 'WORK']]}],
 ['React Native, OOPS, C #t, MVC ,',
  {'entities': [[1, 13, 'SKILLS'],
    [15, 19, 'SKILLS'],
    [21, 23, 'SKILLS'],
    [26, 29, 'SKILLS']]}],
 ['Business Development Associate', {'entities': [[1, 31, 'WORK']]}],
 ['C-language, CSS, HTML ,',
  {'entities': [[1, 11, 'SKILLS'], [13, 16, 'SKILLS'], [18, 22, 'SKILLS']]}],
 ['10/2020 - 3/2021 ,', {'entities': [[1, 17, 'WORK']]}],
 ['Content Writer, Arbitrator ;',
  {'entities': [[1, 15, 'SKILLS'], [17, 27, 'SKILLS']]}],
 ['My role started with contacting potential customer to set up meetings',
  {'entities': [[1, 70, 'WORK']]}],
 ['Client-Interaction, Revenue',
  {'entities': [[1, 19, 'SKILLS'], [21, 28, 'SKILLS']]}],
 ['and favor on closing the deal by describing the diferent pedagogues :',
  {'entities': [[1, 68, 'WORK']]}],
 ['Generation, Business',
  {'entities': [[1, 11, 'SKILLS'], [13, 21, 'SKILLS']]}],
 ['BALMITRA School, Prayagraj', {'entities': [[1, 27, 'EDUCATION']]}],
 ['IT Supervisor & Computer Facilitator',
  {'entities': [[1, 14, 'ACHIEVEMENTS'], [17, 37, 'ACHIEVEMENTS']]}],
 ['Computer Facilitator ;', {'entities': [[1, 21, 'ACHIEVEMENTS']]}],
 ['04/2019 - 02/2020 ,', {'entities': [[1, 18, 'WORK']]}],
 ['Communication Facilitator ;', {'entities': [[1, 26, 'ACHIEVEMENTS']]}],
 ['Managing the smooth working of all the devices for proper work flow',
  {'entities': [[1, 68, 'WORK']]}],
 ['Personality Development', {'entities': [[1, 24, 'ACHIEVEMENTS']]}],
 ['Development Testing ,', {'entities': [[1, 20, 'WORK']]}],
 ['Communication skills ,', {'entities': [[1, 21, 'SKILLS']]}],
 ['Freedom English Academy (A US based NGO), Delhi',
  {'entities': [[1, 24, 'WORK'], [27, 39, 'WORK'], [43, 48, 'WORK']]}],
 ['Research, Originality in', {'entities': [[1, 25, 'WORK']]}],
 ['Personality Development Facilitator', {'entities': [[1, 36, 'WORK']]}],
 ['B.Tech CSE', {'entities': [[1, 11, 'EDUCATION']]}],
 ['Imperial School of Excellence, Prayagraj',
  {'entities': [[1, 41, 'EDUCATION']]}],
 ['Sam Higginbottom University of', {'entities': [[1, 31, 'EDUCATION']]}],
 ['IT Supervisor/ Facilitator and PRO', {'entities': [[1, 27, 'WORK']]}],
 ['Agriculture; Technology & Sciences',
  {'entities': [[1, 12, 'WORK'], [14, 24, 'WORK'], [27, 35, 'WORK']]}],
 ['B.Tech (CSE )', {'entities': [[1, 13, 'EDUCATION']]}],
 ['7.49 CGPA', {'entities': [[1, 10, 'EDUCATION']]}],
 ['07/2012 - 07/2016', {'entities': [[1, 18, 'EDUCATION']]}],
 ['Managing the smooth working of all the devices for proper work flow',
  {'entities': [[1, 68, 'WORK']]}],
 ['related to software and School management system :',
  {'entities': [[1, 49, 'WORK']]}],
 ['Create proper channel of information between management and staff :',
  {'entities': [[1, 66, 'PROJECTS']]}],
 ['Ling Liang High School', {'entities': [[1, 23, 'EDUCATION']]}],
 ['Science (ICSE )', {'entities': [[1, 15, 'EDUCATION']]}],
 ['63.71 %', {'entities': [[1, 7, 'EDUCATION']]}],
 ['and computer programming :', {'entities': [[5, 25, 'SKILLS']]}],
 ['Triffort Tech, Prayagraj', {'entities': [[1, 25, 'EDUCATION']]}],
 ['High School', {'entities': [[1, 12, 'EDUCATION']]}],
 ['Junior Engineer Trainee', {'entities': [[1, 24, 'EDUCATION']]}],
 ['Ling Liang High School', {'entities': [[1, 23, 'EDUCATION']]}],
 ['07/2017 - 11/2017 ,', {'entities': [[1, 18, 'EDUCATION']]}],
 ['Science (ICSE) -.71 %', {'entities': [[1, 21, 'EDUCATION']]}],
 ['Front End development using React Native. Testing and Debugging of Web',
  {'entities': [[1, 64, 'PROJECTS']]}],
 ['AWT', {'entities': [[1, 4, 'SKILLS']]}],
 ['PARSH Tax Solutions, Prayagraj', {'entities': [[1, 31, 'WORK']]}],
 ['Hospital Management System', {'entities': [[1, 27, 'PROJECTS']]}],
 ['Content Writer & Tester', {'entities': [[1, 24, 'PROJECTS']]}],
 ['07/2017 - 11/2017 ,', {'entities': [[1, 18, 'PROJECTS']]}],
 ['Web development with ASP NET and backend',
  {'entities': [[1, 41, 'PROJECTS']]}],
 ['Creating SEO friendly original Content for websites and blogs',
  {'entities': [[1, 62, 'PROJECTS']]}],
 ['Worked on development/ Testing of .Net web modules :',
  {'entities': [[1, 23, 'PROJECTS'], [24, 51, 'PROJECTS']]}],
 ['HCL Technologies', {'entities': [[1, 17, 'WORK']]}],
 ['( 06/2015 - 08/2015 )', {'entities': [[2, 19, 'WORK']]}],
 ['English, Hindi, Bengali, Urdu',
  {'entities': [[1, 8, 'LANGUAGES'],
    [10, 15, 'LANGUAGES'],
    [17, 24, 'LANGUAGES'],
    [26, 30, 'LANGUAGES']]}],
 ['Project Internship on .NET', {'entities': [[1, 27, 'WORK']]}],
 ['MITALI SHARMA', {'entities': [[1, 14, 'NAME ']]}],
 ['GRAPHIC DESIGNER', {'entities': [[1, 17, 'SKILLS']]}],
 ['BEING PASSIONATE AND CREATIVE', {'entities': [[1, 30, 'OTHERS']]}],
 ['Hno. E/B-18, PocKET E, SHATABDI NAGAR ,',
  {'entities': [[1, 38, 'ADDRESS']]}],
 ['DELHI RoAD, MEERUT', {'entities': [[1, 19, 'ADDRESS']]}],
 ['CEL: +91-7409215323', {'entities': [[6, 20, 'CONTACT']]}],
 ['MITALO98212 @ GMAIL.COM', {'entities': [[1, 22, 'EMAIL']]}],
 ['BACHELOR OF FINE ARTS [IVYEAR] IN APPLIED FIELD FROM',
  {'entities': [[1, 22, 'EDUCATION'],
    [24, 30, 'EDUCATION'],
    [35, 53, 'EDUCATION']]}],
 ['LOKACI PRIVATE LTD', {'entities': [[1, 19, 'EDUCATION']]}],
 ['INTERNSHIP 2 MONTH', {'entities': [[1, 19, 'WORK']]}],
 ['KEYWORD INDIA PRIVATE LTD', {'entities': [[1, 26, 'WORK']]}],
 ['THE VIDYA KNOWLEDGE PARK FROM MEERUT, CCS',
  {'entities': [[5, 37, 'WORK']]}],
 ['GRAPHIC DESIGNER', {'entities': [[1, 17, 'WORK']]}],
 ['[ CHAUDHARY CHARAN SINGH UNIVERSITY] WITH AGGREGATE 72 %.',
  {'entities': [[2, 35, 'EDUCATION'], [42, 55, 'EDUCATION']]}],
 ['BRANDMAKER COOPERATION NOIDA SECTOR 63', {'entities': [[1, 39, 'WORK']]}],
 ['HiGH SECONDARY [10+2] FROM MEERUT, CBSE WITH Ist DIVISION',
  {'entities': [[1, 15, 'EDUCATION'],
    [17, 21, 'EDUCATION'],
    [23, 34, 'EDUCATION'],
    [37, 59, 'EDUCATION']]}],
 ['AS GRAPHICE DESICNER: . . (CURRENTLY WORKING )',
  {'entities': [[4, 21, 'WORK'], [28, 45, 'WORK']]}],
 ['HiGH ScHOOL [IO] FROM MEERUT, CBSE WITH IsT DIVISION IN YEAR 2010.',
  {'entities': [[1, 12, 'EDUCATION'],
    [14, 16, 'EDUCATION'],
    [18, 29, 'EDUCATION'],
    [32, 67, 'EDUCATION']]}],
 ['CERTIFICATION COURSE [PuRSUINc ]', {'entities': [[1, 21, 'CERTIFICATES']]}],
 ['4TH MONTH GRAPHIC', {'entities': [[1, 18, 'CERTIFICATES']]}],
 ['DESIGNING [FROM ARENA ANIMATION ]',
  {'entities': [[1, 10, 'CERTIFICATES'], [12, 32, 'CERTIFICATES']]}],
 ['HINDI', {'entities': [[1, 6, 'LANGUAGES']]}],
 ['ENGLISH', {'entities': [[1, 8, 'LANGUAGES']]}],
 ['ADOBE PHOTOSHOP', {'entities': [[1, 16, 'SKILLS']]}],
 ['COREL DARAW', {'entities': [[1, 12, 'SKILLS']]}],
 ['ILLUSRATOE', {'entities': [[1, 11, 'SKILLS']]}],
 ['MANJUL TRIPATHI', {'entities': [[1, 16, 'NAME ']]}],
 ['VILL AND POST HATHEHI- KANPUR NAGAR', {'entities': [[1, 36, 'ADDRESS']]}],
 ['Mobile : 6393576158', {'entities': [[10, 20, 'CONTACT']]}],
 ['manjultripathi123 @ gmail.com', {'entities': [[1, 28, 'EMAIL']]}],
 ['Fresher', {'entities': [[1, 8, 'WORK']]}],
 ['12th from U.P. Board Allahabad in 2018',
  {'entities': [[1, 39, 'EDUCATION']]}],
 ['1oth from U.P. Boar Allahabad in 2015',
  {'entities': [[1, 38, 'EDUCATION']]}],
 ['B.C.A (pursuing).', {'entities': [[1, 16, 'EDUCATION']]}],
 ['COMPUTER PROFICIENCY', {'entities': [[1, 21, 'SKILLS']]}],
 ['M.S: OFFICE, Internet',
  {'entities': [[1, 12, 'SKILLS'], [14, 22, 'SKILLS']]}],
 ['C, C++ and Java :',
  {'entities': [[1, 2, 'SKILLS'], [3, 6, 'SKILLS'], [7, 15, 'SKILLS']]}],
 ['Web programming', {'entities': [[1, 16, 'SKILLS']]}],
 ['HTML, Java Script; PHP and CSS.',
  {'entities': [[1, 5, 'SKILLS'],
    [7, 18, 'SKILLS'],
    [20, 23, 'SKILLS'],
    [28, 31, 'SKILLS']]}],
 ['Database', {'entities': [[1, 9, 'SKILLS']]}],
 ['M.S. Access, My SQL, Oracle',
  {'entities': [[1, 12, 'SKILLS'], [14, 20, 'SKILLS'], [22, 28, 'SKILLS']]}],
 ['Mr. Shashi Bhushan Tripathi', {'entities': [[5, 28, 'FNAME']]}],
 ['1oth August 2001.', {'entities': [[1, 17, 'DOB']]}],
 ['Unmarried', {'entities': [[1, 10, 'STATUS']]}],
 ['Male', {'entities': [[1, 5, 'GENDER']]}],
 ['Indian', {'entities': [[1, 7, 'NATIONALITY']]}],
 ['Hindi, English ,',
  {'entities': [[1, 6, 'LANGUAGES'], [8, 15, 'LANGUAGES']]}],
 ['Comprehensive problem solving abilities, excellent verbal and written communication',
  {'entities': [[15, 30, 'SKILLS'], [42, 58, 'SKILLS'], [63, 84, 'SKILLS']]}],
 ['Skills, ability to deal with people diplomatically, willingness to learn, hard worker :',
  {'entities': [[37, 51, 'SKILLS'], [53, 73, 'SKILLS'], [75, 86, 'SKILLS']]}],
 ['Extrovert', {'entities': [[1, 10, 'SKILLS']]}],
 ['Hard Working', {'entities': [[1, 13, 'SKILLS']]}],
 ['Positive Attitude', {'entities': [[1, 18, 'SKILLS']]}],
 ['Aman Thapar', {'entities': [[1, 12, 'NAME ']]}],
 ['1-308, govind puram ghaziabad; 201013, uttar PRADESH',
  {'entities': [[1, 51, 'ADDRESS']]}],
 ['7827627441 | thaparO04.aman @ rediffmail com, amanthapar438 @ gmail.com',
  {'entities': [[1, 11, 'CONTACT'], [14, 43, 'EMAIL'], [44, 67, 'EMAIL']]}],
 ['Giri consultancy', {'entities': [[1, 17, 'WORK']]}],
 ['2020 - 2021', {'entities': [[1, 12, 'WORK']]}],
 ['Ui/ux designer', {'entities': [[1, 15, 'WORK']]}],
 ['have good hands in bootstrap Demonstrating strong collaboration; communication and organizing skills.',
  {'entities': [[1, 101, 'WORK']]}],
 ['experience in bootstrap javascript: Using html, Css, javascript to create user friendly web pages. Create',
  {'entities': [[15, 24, 'SKILLS'],
    [43, 47, 'SKILLS'],
    [49, 52, 'SKILLS'],
    [54, 64, 'SKILLS']]}],
 ['Ingraham Institute English school ghaziabad',
  {'entities': [[1, 44, 'EDUCATION']]}],
 ['2009', {'entities': [[1, 5, 'EDUCATION']]}],
 ['1Oth class', {'entities': [[1, 11, 'EDUCATION']]}],
 ['Dehradun public school ghaziabad', {'entities': [[1, 33, 'EDUCATION']]}],
 ['2012', {'entities': [[1, 5, 'EDUCATION']]}],
 ['12', {'entities': [[1, 3, 'EDUCATION']]}],
 ['Swami Vivekananda university Sagar madhya pradesh',
  {'entities': [[1, 50, 'EDUCATION']]}],
 ['2016-2020', {'entities': [[1, 10, 'EDUCATION']]}],
 ['Btech cse', {'entities': [[1, 10, 'EDUCATION']]}],
 ['Use html, Css, javascript to create user-friendly web pages. Build highly reusable code. Create functional web',
  {'entities': [[5, 9, 'SKILLS'], [11, 14, 'SKILLS'], [16, 26, 'SKILLS']]}],
 ['html/htmlS, jabascript, css/css3, bootstrap',
  {'entities': [[1, 11, 'SKILLS'],
    [12, 22, 'SKILLS'],
    [23, 31, 'SKILLS'],
    [32, 41, 'SKILLS']]}],
 ['Aswini BK', {'entities': [[1, 10, 'NAME ']]}],
 ['Mahatma Gandhi University, CISAT', {'entities': [[1, 32, 'EDUCATION']]}],
 ['B.Tech in Computer science and engineering , 69% ,',
  {'entities': [[1, 47, 'EDUCATION']]}],
 ['aswinibk93 @ gmail.com', {'entities': [[1, 21, 'EMAIL']]}],
 ['Right soft option, Cochin', {'entities': [[1, 25, 'EMAIL']]}],
 ['8287369329', {'entities': [[1, 11, 'CONTACT']]}],
 ['Php developer (Internship); A% , 2018', {'entities': [[1, 38, 'WORK']]}],
 ['Indian institute of software', {'entities': [[1, 29, 'EDUCATION']]}],
 ['Graphic design (Internship), A+% , 2019', {'entities': [[1, 40, 'WORK']]}],
 ['Excellent IT skills, especially with', {'entities': [[1, 20, 'SKILLS']]}],
 ['Higher secondary examination , 75% , 2013',
  {'entities': [[1, 40, 'EDUCATION']]}],
 ['High school examination , 70% , 2010',
  {'entities': [[1, 35, 'EDUCATION']]}],
 ['Abasoft; Infopark Cochin', {'entities': [[1, 25, 'WORK']]}],
 ['Web designer; Aug 2017 - Sep 2018', {'entities': [[1, 34, 'WORK']]}],
 ['Role: *creating website designs', {'entities': [[8, 33, 'ACHIEVEMENTS']]}],
 ['IMAGE PROCESSING, DATA',
  {'entities': [[1, 17, 'SKILLS'], [19, 23, 'SKILLS']]}],
 ['MINING, BIG DATA', {'entities': [[1, 7, 'SKILLS'], [8, 16, 'SKILLS']]}],
 ['Sixth Sense Media, Karnataka', {'entities': [[1, 28, 'WORK']]}],
 ['UI/UX & Visual Design, Jan 2020', {'entities': [[1, 32, 'WORK']]}],
 ['Dec 2020', {'entities': [[1, 9, 'WORK']]}],
 ['storefronts including Web, Mobile web & handset',
  {'entities': [[27, 37, 'SKILLS']]}],
 ['understanding on android & IOS operating', {'entities': [[1, 41, 'WORK']]}],
 ['Infopark, Cherthala', {'entities': [[1, 21, 'WORK']]}],
 ['UVJ Technologies', {'entities': [[1, 17, 'WORK']]}],
 ['Implant Training at :', {'entities': [[1, 20, 'WORK']]}],
 ['2016-2017', {'entities': [[1, 10, 'WORK']]}],
 ['Computer/Technology', {'entities': [[1, 20, 'SKILLS']]}],
 ['Strong work ethic :', {'entities': [[1, 18, 'SKILLS']]}],
 ['Photography', {'entities': [[1, 12, 'SKILLS']]}],
 ['MrAMARJEET', {'entities': [[1, 11, 'FNAME']]}],
 ['Address: Jamdeeh shukl Basti (UP) 272002',
  {'entities': [[1, 41, 'ADDRESS']]}],
 ['Email: kuamarieet4Z6 @ gmaiLcom', {'entities': [[8, 30, 'EMAIL']]}],
 ['Contact No: +918960197124, +918840434427',
  {'entities': [[13, 26, 'CONTACT'], [27, 40, 'CONTACT']]}],
 ['B. TECH Course in Computer Science from Collage of Engineering Scence and Technology',
  {'entities': [[1, 86, 'EDUCATION']]}],
 ['Lucknow a state goverment', {'entities': [[1, 26, 'EDUCATION']]}],
 ['collage affiliated to Dr: A J Abdul Kalam Technical University ,',
  {'entities': [[1, 63, 'EDUCATION']]}],
 ['COLLAGEISCHOOL', {'entities': [[1, 15, 'EDUCATION']]}],
 ['B. Tech', {'entities': [[1, 8, 'EDUCATION']]}],
 ['AKTU', {'entities': [[1, 5, 'EDUCATION']]}],
 ['2020', {'entities': [[1, 5, 'EDUCATION']]}],
 ['Collage of Engineering Science and', {'entities': [[1, 35, 'EDUCATION']]}],
 ['77.66', {'entities': [[1, 6, 'EDUCATION']]}],
 ['Technology, Lucknow', {'entities': [[1, 20, 'EDUCATION']]}],
 ['Class XII', {'entities': [[1, 10, 'EDUCATION']]}],
 ['U.P Board', {'entities': [[1, 10, 'EDUCATION']]}],
 ['2014', {'entities': [[1, 5, 'EDUCATION']]}],
 ['AG.VHS.S. BANKAISIYA', {'entities': [[1, 21, 'EDUCATION']]}],
 ['69.3', {'entities': [[1, 5, 'EDUCATION']]}],
 ['MAJHAWA BASTI', {'entities': [[1, 14, 'EDUCATION']]}],
 ['Class X', {'entities': [[1, 8, 'EDUCATION']]}],
 ['U.P Board', {'entities': [[1, 10, 'EDUCATION']]}],
 ['2012', {'entities': [[1, 5, 'EDUCATION']]}],
 ['A.G.VHS.S. BANKAISIYA', {'entities': [[1, 22, 'EDUCATION']]}],
 ['74', {'entities': [[1, 3, 'EDUCATION']]}],
 ['MAJHAWA BASTI', {'entities': [[1, 14, 'EDUCATION']]}],
 ['Language: HTML, CSS, Bootstrap, PHP; Basic laravel, Javascript and C',
  {'entities': [[11, 15, 'SKILLS'],
    [17, 20, 'SKILLS'],
    [22, 31, 'SKILLS'],
    [33, 36, 'SKILLS'],
    [38, 51, 'SKILLS'],
    [53, 63, 'SKILLS'],
    [68, 69, 'SKILLS']]}],
 ['Oprating System: Windows and Linux',
  {'entities': [[18, 25, 'SKILLS'], [30, 35, 'SKILLS']]}],
 ['Six weeks summer training in Core PHP',
  {'entities': [[1, 38, 'CERTIFICATES']]}],
 ['Seekware Pvt. Ltd.', {'entities': [[1, 18, 'WORK']]}],
 ['Fornt-end Developer :', {'entities': [[1, 20, 'WORK']]}],
 ['12/07/2021 Joining date.', {'entities': [[1, 24, 'WORK']]}],
 ['" School Management System ": Built a web page for the school using php as a backend ,',
  {'entities': [[2, 26, 'PROJECTS'], [30, 84, 'PROJECTS']]}],
 ['Admin login, view profile, insert update and delete :',
  {'entities': [[1, 12, 'PROJECTS'],
    [14, 26, 'PROJECTS'],
    [28, 41, 'PROJECTS']]}],
 ['Positive Attitude: Responsible, Effective Planning; Team facilitator; motivating Power',
  {'entities': [[1, 18, 'SKILLS'],
    [20, 31, 'SKILLS'],
    [33, 51, 'SKILLS'],
    [53, 69, 'SKILLS'],
    [71, 87, 'SKILLS']]}],
 ['15/07/1997', {'entities': [[1, 11, 'DOB']]}],
 ['Mr Harimangal', {'entities': [[1, 14, 'FNAME']]}],
 ['Male', {'entities': [[1, 5, 'GENDER']]}],
 ['Indian', {'entities': [[1, 7, 'STATUS']]}],
 ['Playing chess, Book reading',
  {'entities': [[1, 14, 'OTHERS'], [16, 28, 'OTHERS']]}],
 ['Hindi English', {'entities': [[1, 6, 'LANGUAGES'], [7, 14, 'LANGUAGES']]}],
 ['Confident; Ability to learn Quickly and convince others',
  {'entities': [[1, 56, 'OTHERS']]}],
 ['2018 to 2021', {'entities': [[1, 13, 'EDUCATION']]}],
 ["Bachelor's degree in BCA", {'entities': [[1, 25, 'EDUCATION']]}],
 ['Chaudhary charan singh University', {'entities': [[1, 34, 'EDUCATION']]}],
 ['Meerut; Uttar Pradesh', {'entities': [[1, 14, 'EDUCATION']]}],
 ['Intermediate in PCM', {'entities': [[1, 20, 'EDUCATION']]}],
 ['CBSE Board', {'entities': [[1, 11, 'EDUCATION']]}],
 ['High School', {'entities': [[1, 12, 'EDUCATION']]}],
 ['CBSE Board', {'entities': [[1, 11, 'EDUCATION']]}],
 ['HTMLS', {'entities': [[1, 6, 'SKILLS']]}],
 ['CSS', {'entities': [[1, 4, 'SKILLS']]}],
 ['JavaScript', {'entities': [[1, 11, 'SKILLS']]}],
 ['Hindi', {'entities': [[1, 6, 'LANGUAGES']]}],
 ['English', {'entities': [[1, 8, 'LANGUAGES']]}],
 ['Commitment and capacity to work independently :',
  {'entities': [[1, 46, 'OTHERS']]}],
 ['Highly Enthusiastic', {'entities': [[1, 20, 'OTHERS']]}],
 ['Quick learner', {'entities': [[1, 14, 'OTHERS']]}],
 ['AARIF KHAN', {'entities': [[1, 11, 'NAME ']]}],
 ['Block L-Znd; House No. 894, Gali No. 20, Shani Bazar ,',
  {'entities': [[1, 52, 'ADDRESS']]}],
 ['Bandh Road, Sangam Vihar; New Delhi - 110080',
  {'entities': [[1, 45, 'ADDRESS']]}],
 ['8802983341', {'entities': [[1, 11, 'CONTACT']]}],
 ['aarifkhan7896 @ gmail.com', {'entities': [[1, 24, 'EMAIL']]}],
 ['https: Ilwww.linkedin comlinlaarifkhan7896',
  {'entities': [[1, 42, 'LINKS']]}],
 ['To achieve a growth-oriented position in a reputed organization where',
  {'entities': [[1, 70, 'OTHERS']]}],
 ['JAVA, PHP, HTML, CSS, JAVASCRIPT ,',
  {'entities': [[1, 5, 'SKILLS'],
    [7, 10, 'SKILLS'],
    [12, 16, 'SKILLS'],
    [18, 21, 'SKILLS'],
    [23, 33, 'SKILLS']]}],
 ['JQUERY, BOOTSTRAP', {'entities': [[1, 7, 'SKILLS'], [9, 18, 'SKILLS']]}],
 ['MYSQL', {'entities': [[1, 6, 'SKILLS']]}],
 ['PHOTOSHOP, MICROSOFT OFFICE',
  {'entities': [[1, 10, 'SKILLS'], [13, 29, 'SKILLS']]}],
 ['POST GRADUATION , 2019-2021', {'entities': [[1, 27, 'EDUCATION']]}],
 ['have developed a portfolio using', {'entities': [[1, 33, 'PROJECTS']]}],
 ['MCA', {'entities': [[1, 4, 'EDUCATION']]}],
 ['Dr. AP.J Abdul Kalam Technical University ,',
  {'entities': [[1, 42, 'EDUCATION']]}],
 ['HTML, CSS and JavaScript which is fully',
  {'entities': [[1, 40, 'PROJECTS']]}],
 ['Lucknow, Uttar Pradesh', {'entities': [[1, 23, 'PROJECTS']]}],
 ['have mentioned my technical', {'entities': [[1, 28, 'PROJECTS']]}],
 ['8.35 CGPA (83.5% )', {'entities': [[1, 19, 'EDUCATION']]}],
 ['skills and projects in my portfolio.', {'entities': [[1, 36, 'PROJECTS']]}],
 ['https Ilaarifkhan7896 github io/', {'entities': [[1, 33, 'LINKS']]}],
 ['GRADUATION , 2015-2018', {'entities': [[1, 22, 'LINKS']]}],
 ['BCA / Jamia Hamdard University, Hamdard Nagar ,',
  {'entities': [[1, 46, 'LINKS']]}],
 ['64.9 %', {'entities': [[1, 7, 'EDUCATION']]}],
 ['SENIOR SECONDARY , 2015', {'entities': [[1, 23, 'EDUCATION']]}],
 ['12th / Red Roses Public School, Saket, Delhi',
  {'entities': [[1, 45, 'EDUCATION']]}],
 ['59.4%, CBSE', {'entities': [[1, 13, 'EDUCATION']]}],
 ['Library_Management_System :', {'entities': [[1, 26, 'PROJECTS']]}],
 ['management system is ERP software that',
  {'entities': [[1, 34, 'PROJECTS']]}],
 ['SECONDARY , 2013', {'entities': [[1, 16, 'EDUCATION']]}],
 ['10th / Red Roses Public School, Saket; Delhi',
  {'entities': [[1, 45, 'EDUCATION']]}],
 ['7.2 CGPA (68.4 %), CBSE', {'entities': [[1, 24, 'EDUCATION']]}],
 ['using PHP.', {'entities': [[7, 10, 'SKILLS']]}],
 ['Creative and Innovative', {'entities': [[1, 24, 'OTHERS']]}],
 ['07-08-1996', {'entities': [[1, 11, 'DOB']]}],
 ['Male', {'entities': [[1, 5, 'GENDER']]}],
 ['Ibrahim Khan', {'entities': [[1, 13, 'FNAME']]}],
 ['Quick Learner and Hard Worker.',
  {'entities': [[1, 14, 'SKILLS'], [19, 30, 'SKILLS']]}],
 ['Indian', {'entities': [[1, 7, 'NATIONALITY']]}],
 ['Unmarried', {'entities': [[1, 10, 'STATUS']]}],
 ['English, Hindi, Urdu & Arabic',
  {'entities': [[1, 8, 'LANGUAGES'],
    [10, 15, 'LANGUAGES'],
    [17, 21, 'LANGUAGES'],
    [24, 30, 'LANGUAGES']]}],
 ['Certificate of Completion of " Java (JZSE & JZEE) " from',
  {'entities': [[1, 26, 'CERTIFICATES'], [31, 49, 'CERTIFICATES']]}],
 ['F-Tech; Khanpur :', {'entities': [[1, 16, 'CERTIFICATES']]}],
 ['Certificate of Completion of " Introduction to Full Stack',
  {'entities': [[1, 57, 'CERTIFICATES']]}],
 ['Development " from Great Learning :',
  {'entities': [[1, 33, 'CERTIFICATES']]}],
 ['Certificate of Completion of " The Fundamentals of Digital',
  {'entities': [[1, 58, 'CERTIFICATES']]}],
 ['Marketing " from Google Digital Garage.',
  {'entities': [[1, 38, 'CERTIFICATES']]}],
 ['Certificate of Participation of', {'entities': [[1, 33, 'CERTIFICATES']]}],
 ["Android Workshop'", {'entities': [[1, 18, 'CERTIFICATES']]}],
 ['GNIOT Tech club', {'entities': [[1, 16, 'ACHIEVEMENTS']]}],
 ['AARIF KHAN', {'entities': [[1, 11, 'NAME ']]}]]

# %%
optimizer = nlp.begin_training()
for i in range(20):
    random.shuffle(TRAIN_DATA)
    for text, annotations in TRAIN_DATA:
        nlp.update([text], [annotations],drop=0.3, sgd=optimizer)


text = "But Modi is starting India. The company made a late push\ninto hardware, and Apple’s Siri and Google available on iPhones, and Amazon’s Alexa\nsoftware, which runs on its Echo and Dot devices, have clear leads in\nconsumer adoption."
doc = nlp(text)
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6944/2060852413.py in <module>
#       3     random.shuffle(TRAIN_DATA)
#       4     for text, annotations in TRAIN_DATA:
# ----> 5         nlp.update([text], [annotations],drop=0.3, sgd=optimizer)
#       6
#       7
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\spacy\language.py in update(self, docs, golds, drop, sgd, losses, component_cfg)
#     527             kwargs = component_cfg.get(name, {})
#     528             kwargs.setdefault("drop", drop)
# --> 529             proc.update(docs, golds, sgd=get_grads, losses=losses, **kwargs)
#     530             for key, (W, dW) in grads.items():
#     531                 sgd(W, dW, key=key)
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.update()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser._init_gold_batch()
#
# ...

# %%
for text, annotations in TRAIN_DATA:
    print(text,annotations)
# Out:
# Modi {'entities': [(0, 4, 'CELEBRITY')]}

# %%
training_data["annotations"]
# Out:
# [['Meanwhile, for the September quarter, the company reported a consolidated net loss of Rs 184.06 crore versus a net profit of Rs 47.67 crore in the year ago quarter.',
#   {'entities': [[86, 101, 'MONEY'], [125, 139, 'MONEY']]}],
#  ['Sood further said that they have brought down the fixed cost down by almost 75-80 percent.',
#   {'entities': [[0, 4, 'NAME'], [76, 89, 'PERCENTAGE']]}],
#  ['The company managed to get rent waivers from most landlords, CFO Nitin Sood said in an interview to CNBC-TV18. “The big focus for us right now as revenues have been nil is to really reduce our fixed cost and we have managed to do that, ” he added.',
#   {'entities': [[61, 64, 'ROLE'], [65, 75, 'NAME']]}],
# ...

# %%
optimizer = nlp.begin_training()
for i in range(20):
    random.shuffle(training_data["annotations"])
    for text, annotations in training_data["annotations"]:
        nlp.update([text], [annotations],drop=0.3, sgd=optimizer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-bed82b39c9bf> in <module>
#       3     random.shuffle(training_data["annotations"])
#       4     for text, annotations in training_data["annotations"]:
# ----> 5         nlp.update([text], [annotations],drop=0.3, sgd=optimizer)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/spacy/language.py in update(self, docs, golds, drop, sgd, losses, component_cfg)
#     527             kwargs = component_cfg.get(name, {})
#     528             kwargs.setdefault("drop", drop)
# --> 529             proc.update(docs, golds, sgd=get_grads, losses=losses, **kwargs)
#     530             for key, (W, dW) in grads.items():
#     531                 sgd(W, dW, key=key)
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.update()
#
# ...

# %%
for text, annotations in training_data["annotations"]:
    print(len(text),len([annotations]))
# Out:
# 164 1
# 90 1
# 247 1
# 337 1
# 0 1
# 318 1
# 0 1
# 180 1
# 210 1
# 103 1
# 209 1
# 92 1

# %%
text = "The share price of PVR rose over 7 percent on Wednesday after the multiplex chain said that it has reduced losses in Q2 despite nil revenue from the core movie exhibition business. The company managed to get rent waivers from most landlords, CFO Nitin Sood said in an interview to CNBC-TV18. “The big focus for us right now as revenues have been nil is to really reduce our fixed cost and we have managed to do that,” he added. Sood further said that they have brought down the fixed cost down by almost 75-80 percent. The stock rose as much as 7.6 percent to the day's high of Rs 1,186.85 per share on the BSE.Meanwhile, for the September quarter, the company reported a consolidated net loss of Rs 184.06 crore versus a net profit of Rs 47.67 crore in the year ago quarter. Its total income was at Rs 110.61 crore during the quarter under review against Rs 979.40 crore in the corresponding quarter last fiscal. PVR's total expenses were at Rs 389.37 crore in July-September 2020-21.Financial performance of the company for Q2, FY 21 was impacted by the continued lockdown announced due to COVID-19 outbreak, which disrupted the company's operations, said PVR in a post-earnings statement. PVR said its results were not comparable as business was impacted due to temporary closures of cinemas.Under Unlock 5.0 guidelines, the government has permitted cinemas to reopen October 15 onwards with 50 percent capacity. So far, 16 states and UTs, where PVR has a presence, have permitted cinemas to restart operations. Out of total of 831 screens of the company, over 575 have received permission to reopen, it said.PVR Ltd Chairman cum Managing Director Ajay Bijli said: We are eagerly waiting for the reopening of other states, specifically Maharashtra and Telangana so that business can gradually get back to normal. We are taking all possible precautions so that both our customers and employees feel safe while visiting their favourite cinema."

# %%
doc = nlp(text)
for ent in doc.ents:
    print(ent.text,ent.label_)
# Out:
# 7 percent PERCENT
# Wednesday DATE
# as much as 7.6 percent PERCENT
# day DATE
# Rs 1,186.85 MONEY
# Rs 184.06 MONEY
# Rs 47.67 crore MONEY
# Rs 110.61 MONEY
# Rs 979.40 MONEY
# Rs 389.37 MONEY
# October 15 DATE
# 50 percent PERCENT
# Managing Director Ajay Bijli ORG
# Maharashtra ORG
# Telangana PERSON
